# %%
# Load LSTM network and generate text
import sys
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
import pandas as pd
# Out:
# C:\Users\rujjn\Anaconda3\envs\capstone2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
docs = pd.read_pickle('training_set.pkl')


# for clarity, rename numbered essay topics to one-word topic summary 

topic_dict = {'topic':{1: 'computers', 
                       2: 'censorship', 
                       3: 'cyclist', 
                       4: 'hibiscus', 
                       5: 'mood', 
                       6: 'dirigibles', 
                       7: 'patience', 
                       8: 'laughter'}}

docs.replace(topic_dict, inplace=True)

docs.head()
# Out:
#    essay_id      topic                                              essay  \
# 0         1  computers  Dear local newspaper, I think effects computer...
# 1         2  computers  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3  computers  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4  computers  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5  computers  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  target_score  \
# 0               4               4             NaN             8
# 1               5               4             NaN             9
# 2               4               3             NaN             7
# 3               5               5             NaN            10
# 4               4               4             NaN             8
#
#    rater1_domain2  rater2_domain2  topic2_target  \
# 0             NaN             NaN            NaN
# 1             NaN             NaN            NaN
# 2             NaN             NaN            NaN
# 3             NaN             NaN            NaN
# 4             NaN             NaN            NaN
#
#                          ...                          rater3_trait2  \
# 0                        ...                                    NaN
# 1                        ...                                    NaN
# 2                        ...                                    NaN
# 3                        ...                                    NaN
# 4                        ...                                    NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6  char_len  \
# 0            NaN            NaN            NaN            NaN      1875
# 1            NaN            NaN            NaN            NaN      2288
# 2            NaN            NaN            NaN            NaN      1541
# 3            NaN            NaN            NaN            NaN      3165
# 4            NaN            NaN            NaN            NaN      2569
#
#    word_count                                             tokens  \
# 0         351  [Dear, local, newspaper, ,, I, think, effects,...
# 1         424  [Dear, @CAPS1, @CAPS2, ,, I, believe, that, us...
# 2         284  [Dear, ,, @CAPS1, @CAPS2, @CAPS3, More, and, m...
# 3         531  [Dear, Local, Newspaper, ,, @CAPS1, I, have, f...
# 4         474  [Dear, @LOCATION1, ,, I, know, having, compute...
#
#                                                lemma  \
# 0  [dear, local, newspaper, ,, -PRON-, think, eff...
# 1  [dear, @caps1, @caps2, ,, -PRON-, believe, tha...
# 2  [dear, ,, @caps1, @caps2, @caps3, more, and, m...
# 3  [dear, local, newspaper, ,, @caps1, -PRON-, ha...
# 4  [dear, @location1, ,, -PRON-, know, have, comp...
#
#                                                  pos
# 0  [ADJ, ADJ, NOUN, PUNCT, PRON, VERB, NOUN, NOUN...
# 1  [ADJ, PROPN, PUNCT, PUNCT, PRON, VERB, ADP, VE...
# 2  [ADJ, PUNCT, PROPN, PUNCT, PROPN, ADJ, CCONJ, ...
# 3  [ADJ, PROPN, PROPN, PUNCT, PROPN, PRON, VERB, ...
# 4  [ADJ, ADP, PUNCT, PRON, VERB, VERB, NOUN, VERB...
#
# [5 rows x 33 columns]

# %%
# load ascii text and covert to lowercase
raw_text = docs[((docs.topic == 'computers') &
            (docs.target_score > 6)) |
            ((docs.topic == 'censorship') & 
            (docs.target_score > 2))]\
            ['essay'].to_string().lower()

# %%
# create mapping of unique chars to integers, and a reverse mapping
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)
# Out:
# Total Characters:  188557
# Total Vocab:  56

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)
# Out:
# Total Patterns:  188457

# %%
# reshape X to be [samples, time steps, features]
X = np.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2, seed=42))
model.add(Dense(y.shape[1], activation='softmax'))

# %%
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# fit the model
model.fit(X, y, epochs=20, batch_size=128, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 188457/188457 [==============================] - 711s 4ms/step - loss: 2.2928
#
# Epoch 00001: loss improved from inf to 2.29283, saving model to weights-improvement-01-2.2928.hdf5
# Epoch 2/20
# 188457/188457 [==============================] - 720s 4ms/step - loss: 1.7295
#
# Epoch 00002: loss improved from 2.29283 to 1.72952, saving model to weights-improvement-02-1.7295.hdf5
# Epoch 3/20
# 188457/188457 [==============================] - 726s 4ms/step - loss: 1.4968
#
# Epoch 00003: loss improved from 1.72952 to 1.49683, saving model to weights-improvement-03-1.4968.hdf5
# Epoch 4/20
# 188457/188457 [==============================] - 727s 4ms/step - loss: 1.4059
#
# Epoch 00004: loss improved from 1.49683 to 1.40586, saving model to weights-improvement-04-1.4059.hdf5
# Epoch 5/20
# 188457/188457 [==============================] - 724s 4ms/step - loss: 1.3409
#
# Epoch 00005: loss improved from 1.40586 to 1.34094, saving model to weights-improvement-05-1.3409.hdf5
# Epoch 6/20
# 188457/188457 [==============================] - 729s 4ms/step - loss: 1.2981
#
# Epoch 00006: loss improved from 1.34094 to 1.29806, saving model to weights-improvement-06-1.2981.hdf5
# Epoch 7/20
# 188457/188457 [==============================] - 806s 4ms/step - loss: 1.2667
#
# Epoch 00007: loss improved from 1.29806 to 1.26667, saving model to weights-improvement-07-1.2667.hdf5
# Epoch 8/20
#   4608/188457 [..............................] - ETA: 12:14 - loss: 1.2235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-6737de4f07d1> in <module>()
#       1 # fit the model
# ----> 2 model.fit(X, y, epochs=20, batch_size=128, callbacks=callbacks_list)
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\envs\capstone2\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
# Load weights from most improved
filename = "weights-improvement-07-1.2667.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# pick a random seed
start = np.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print("Seed:")
print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
# Out:
# Seed:
# " ..
# 500     dear local newspaper, i believe that there is ...
# 501     click, click, click, "@caps1!"  "

# %%
def sample_prediction(prediction):
    """Get rand index from preds based on its prob distribution.

    Params
    ——
    prediction (array (array)): array of length 1 containing array of probs that sums to 1

    Returns
    ——-
    rnd_idx (int): random index from prediction[0]

    Notes
    —–
    Helps to solve problem of repeated outputs.

    len(prediction) = 1
    len(prediction[0]) >> 1
    """
    X = prediction[0] # sum(X) is approx 1
    rnd_idx = np.random.choice(len(X), p=X)
    return rnd_idx

# %%
generated = ''
for i in range(400):
    x = np.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = sample_prediction(prediction)
    result = int_to_char[index]
#     sys.stdout.write(result)
    generated += result
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
print('\nDone.')
print(generated)
# Out:
# Done.
#  io...
# 3769    loardnien th aln naad thatn oooedss on iaseri...
# 3756    neaen of bla wo hir an wei iase awo aia nerplew...
# 3464    'ala oaipns late npro ne avehngl wod vhia?a ...
# 2020    enool, alc wu suehkog toaying tlec cdgt l .m.. 3855    dv yaiki eeo oeopon mggin oo doc ypui o?..
# 2063    oele yhu enefrs thebokn to tienefta kive ms...
# 2442    iave you ever todii teak c bloct dnocd ten t ...
# 235
