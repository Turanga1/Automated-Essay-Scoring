# %%
# Import necessary modules

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import string
import re

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import cross_val_score, KFold

from gensim.models.word2vec import Word2Vec

# from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords
from nltk.corpus import stopwords
import language_check
import spacy

from skll.metrics import kappa
from scipy.sparse import csr_matrix

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Input, LSTM, Embedding, Bidirectional, Flatten
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from keras.optimizers import SGD, Adam
from keras.wrappers.scikit_learn import KerasRegressor

nlp = spacy.load('en')

stopwords = stopwords.words('english')

# %matplotlib inline

print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Seaborn version:', sns.__version__)
# Out:
# C:\Users\rujjn\Anaconda3\envs\capstone2\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\Users\rujjn\Anaconda3\envs\capstone2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Numpy version: 1.14.3
# Pandas version: 0.23.2
# Seaborn version: 0.8.1

# %% [markdown]
# ## Process Overview
#
# ### Apply grammar and spelling corrections
#
# Feature importances generated from the extra trees algorithm did not rank grammar and spelling errors highly, suggesting that perhaps the essays could be processed "as is". On the other hand, word embeddings rely on known words and many usage examples. Misspelled words will either be ignored if their count is below the minimum, or worse, if misspelled to an existing word with a different meaning, the vectors could change the performance of the model in a way that might not be useful. LanguageTool will be used for applying these corrections.
#
# ### Clean essays
#
# Remove less helpful parts of essay texts, i.e. punctuation, pronouns and capital letters and return lemma to be processed into word embeddings. SpaCy is a simple and efficient tool for this task.
#
# ### Generate word embeddings
#
# SpaCy could also be used to generate word embeddings, however its simple 'en' language model is trained on a corpus that is very different from school essays. It also uses context sensitive tensors which don't provide specific word vectors. Instead, Gensim's Word2Vec is used to generate a model based on the all available essays, i.e. the "training_set" which includes target scores and the "validation" and "test" sets which do not have target scores. Finally, cleaned essays of the "training_set" will be passed into the word model to generate average 300-dimensional word vectors.
#
# ### Prepare inputs
#
# There are eight topics which each have a different scale for scoring. To deal with this there are several possible approaches. First, each topic could be processed individually and the resultant kappa scores would be averaged. This approach is useful if certain features are particularly useful for grading a specific topic. On the other hand, fewer essays mean fewer examples to learn from.
#
# An alternate approach is to combine all topics by scaling the scores with a min-max scaler to a common range, e.g. 0-60. This approach increases the number of examples nearly 8-fold.
#
# ### Classification or regression?
#
# Automatic scoring can now be thought of as either a classification or a regression problem. For classification the target variable needs to be one-hot encoded to the range of unique target scores and the output layer of the neural network also needs to have the same dimension. For regression, the target variable and output layer have a single dimension. Where the classification results are approximated or rounded through `softmax` activation and again when reversing the min-max scaling, the regression results are only rounded after scaling. This might be the reason regression performs slightly better on this data set.

# %%
def correct_language(df):
    """
    use language tool to correct for most spelling and grammatical errors. Also count the applied corrections. 
    Using language_check python wrapper for languagetool:
    https://www.languagetool.org/dev
    """
    tool = language_check.LanguageTool('en-US')

    df['matches'] = df['essay'].apply(lambda txt: tool.check(txt))
    df['corrections'] = df.apply(lambda l: len(l['matches']), axis=1)
    df['corrected'] = df.apply(lambda l: language_check.correct(l['essay'], l['matches']), axis=1)
      
    return df

# %%
# read essays from training_set
training_set  = pd.read_csv('training_set_rel3.tsv', sep='\t', encoding = "ISO-8859-1")\
            .rename(columns={'essay_set': 'topic', 'domain1_score': 'target_score', 'domain2_score': 'topic2_target'})

# apply spelling and grammar corrections
training_set = correct_language(training_set)

training_set.head()
# Out:
#    essay_id  topic                                              essay  \
# 0         1      1  Dear local newspaper, I think effects computer...
# 1         2      1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3      1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4      1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5      1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  target_score  \
# 0               4               4             NaN             8
# 1               5               4             NaN             9
# 2               4               3             NaN             7
# 3               5               5             NaN            10
# 4               4               4             NaN             8
#
#    rater1_domain2  rater2_domain2  topic2_target  \
# 0             NaN             NaN            NaN
# 1             NaN             NaN            NaN
# 2             NaN             NaN            NaN
# 3             NaN             NaN            NaN
# 4             NaN             NaN            NaN
#
#                          ...                          rater2_trait6  \
# 0                        ...                                    NaN
# 1                        ...                                    NaN
# 2                        ...                                    NaN
# 3                        ...                                    NaN
# 4                        ...                                    NaN
#
#    rater3_trait1  rater3_trait2  rater3_trait3  rater3_trait4  rater3_trait5  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait6                                            matches  \
# 0            NaN  [Line 1, column 219, Rule ID: MORFOLOGIK_RULE_...
# 1            NaN  [Line 1, column 149, Rule ID: MORFOLOGIK_RULE_...
# 2            NaN  [Line 1, column 316, Rule ID: MORFOLOGIK_RULE_...
# 3            NaN  [Line 1, column 87, Rule ID: MORFOLOGIK_RULE_E...
# 4            NaN  [Line 1, column 178, Rule ID: MORFOLOGIK_RULE_...
#
#    corrections                                          corrected
# 0           11  Dear local newspaper, I think effects computer...
# 1           19  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            9  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3           35  Dear Local Newspaper, @CAPS1 I have found that...
# 4           17  Dear @LOCATION1, I know having computers has a...
#
# [5 rows x 31 columns]

# %%
valid_set
# Out:
#       essay_id  topic                                              essay  \
# 0         1788      1  Dear @ORGANIZATION1, @CAPS1 more and more peop...
# 1         1789      1  Dear @LOCATION1 Time @CAPS1 me tell you what I...
# 2         1790      1  Dear Local newspaper, Have you been spending a...
# 3         1791      1  Dear Readers, @CAPS1 you imagine how life woul...
# 4         1792      1  Dear newspaper, I strongly believe that comput...
# 5         1793      1  Dear local newspaper, @CAPS1 the caveman found...
# 6         1794      1  Dear newspaper editor, @CAPS1 now is a letter ...
# 7         1795      1  Dear @ORGANIZATION1, @CAPS1, there has been so...
# 8         1796      1  Dear Local Newspaper, I would like to complain...
# 9         1797      1  Dear Newspaper, @CAPS1 having kids wasting the...
# 10        1798      1  Dear @CAPS1 @CAPS2, @CAPS3 should think that c...
# 11        1799      1  Dear Local @CAPS1, Computers, and other techno...
# 12        1800      1  Why people should use computers? Computers are...
# 13        1801      1  @CAPS1, its time for supper! @CAPS2 on, mom I ...
# 14        1802      1  Dear local newspaper: I am writing this letter...
# 15        1803      1  Effects of computers @CAPS1 local newspaper, H...
# 16        1804      1  Dear to whom it @MONTH1 concern, @CAPS1 is an ...
# 17        1805      1  Dear @ORGANIZATION1, Advances in technology ca...
# 18        1806      1  Dear newspaper @CAPS1, I am writing this lette...
# 19        1807      1  Dear Local newspaper, I do agree that to many ...
# 20        1808      1  Dear Local Newspaper, I heard about people's o...
# 21        1809      1  Dear @CAPS1, I believe that computers have an ...
# 22        1810      1  Although some people believe computers aren't ...
# 23        1811      1  Computors are looked at as either friend or fo...
# 24        1812      1  Dear local Newspaper, I am writing to you toda...
# 25        1814      1  Dear news paper, Computers are good for people...
# 26        1815      1  Dear @CAPS1 @CAPS2 Newspaper, Have you ever wa...
# 27        1816      1  Dear Newspaper. I @CAPS2 that people are spend...
# 28        1817      1  Dear @ORGANIZATION1, Computers have bad effect...
# 29        1818      1  Dear @CAPS1, @CAPS2 name is @CAPS3 @CAPS4. I g...
# ...        ...    ...                                                ...
# 4188     21902      8  Just @CAPS1 @CAPS2 @DATE1 is @LOCATION2's @CAP...
# 4189     21903      8  Dad's @CAPS1 In the not so distant past I need...
# 4190     21904      8   It's that amazing feeling in your core, where...
# 4191     21905      8   @PERSON1 sits at a table, working on an art p...
# 4192     21906      8     Have you ever been furious enough to cry ? ...
# 4193     21908      8   Once when I was on my way over to my best fri...
# 4194     21910      8   My mom and I have a unique relationship. She ...
# 4195     21911      8   This test is a bunch of crap and its funny th...
# 4196     21912      8   Working at the local glass factory is not nec...
# 4197     21913      8  The @ORGANIZATION2 and I @CAPS1 to the @CAPS2 ...
# 4198     21915      8   Over this last @DATE1 some friends and I were...
# 4199     21916      8     Have you ever had a really bad day and noth...
# 4200     21917      8                                  LaughterLaught...
# 4201     21918      8  Laughter is a tool that every one knows how to...
# 4202     21919      8   Laughter is a good part of life. It demonstra...
# 4203     21921      8  It all started off on a cold sunny @DATE1 @TIM...
# 4204     21922      8  There have been many times in my life that I h...
# 4205     21923      8   The sunset shimmers off of the sparkling wate...
# 4206     21924      8    Laughter has played a significant role in my...
# 4207     21925      8   In the @DATE1 ,my best friend @PERSON1 and I ...
# 4208     21926      8    My friends and I always have a great time to...
# 4209     21927      8    Everybody laughs in their life time, sometim...
# 4210     21928      8   Laughter to me is important in any relationsh...
# 4211     21929      8   I believe that laughter is a huge part of any...
# 4212     21932      8                         laughter is the best me...
# 4213     21933      8   Have you ever noticed that if two little kids...
# 4214     21934      8                              Laughter @CAPS1 I ...
# 4215     21935      8   Laughter in @CAPS1 A laugh is not just an act...
# 4216     21937      8    LAUGHTER @CAPS1 i was younger my friend live...
# 4217     21938      8   You know how the saying goes live, laugh, lov...
#
#       domain1_predictionid  domain2_predictionid
# 0                     1788                   NaN
# 1                     1789                   NaN
# 2                     1790                   NaN
# 3                     1791                   NaN
# 4                     1792                   NaN
# 5                     1793                   NaN
# 6                     1794                   NaN
# 7                     1795                   NaN
# 8                     1796                   NaN
# 9                     1797                   NaN
# 10                    1798                   NaN
# 11                    1799                   NaN
# 12                    1800                   NaN
# 13                    1801                   NaN
# 14                    1802                   NaN
# 15                    1803                   NaN
# 16                    1804                   NaN
# 17                    1805                   NaN
# 18                    1806                   NaN
# 19                    1807                   NaN
# 20                    1808                   NaN
# 21                    1809                   NaN
# 22                    1810                   NaN
# 23                    1811                   NaN
# 24                    1812                   NaN
# 25                    1814                   NaN
# 26                    1815                   NaN
# 27                    1816                   NaN
# 28                    1817                   NaN
# 29                    1818                   NaN
# ...                    ...                   ...
# 4188                 24902                   NaN
# 4189                 24903                   NaN
# 4190                 24904                   NaN
# 4191                 24905                   NaN
# 4192                 24906                   NaN
# 4193                 24908                   NaN
# 4194                 24910                   NaN
# 4195                 24911                   NaN
# 4196                 24912                   NaN
# 4197                 24913                   NaN
# 4198                 24915                   NaN
# 4199                 24916                   NaN
# 4200                 24917                   NaN
# 4201                 24918                   NaN
# 4202                 24919                   NaN
# 4203                 24921                   NaN
# 4204                 24922                   NaN
# 4205                 24923                   NaN
# 4206                 24924                   NaN
# 4207                 24925                   NaN
# 4208                 24926                   NaN
# 4209                 24927                   NaN
# 4210                 24928                   NaN
# 4211                 24929                   NaN
# 4212                 24932                   NaN
# 4213                 24933                   NaN
# 4214                 24934                   NaN
# 4215                 24935                   NaN
# 4216                 24937                   NaN
# 4217                 24938                   NaN
#
# [4218 rows x 5 columns]

# %%
# read essays from validation and test sets

valid_set  = pd.read_csv('valid_set.tsv', sep='\t', encoding = "ISO-8859-1")\
            .rename(columns={'essay_set': 'topic'})
test_set  = pd.read_csv('test_set.tsv', sep='\t', encoding = "ISO-8859-1")\
            .rename(columns={'essay_set': 'topic'})

combo_set = pd.concat([valid_set, test_set], sort=False)

# apply spelling and grammar corrections
combo_set = correct_language(combo_set)

# %%
combo_set = pd.concat([combo_set, training_set], sort=False)
combo_set.to_pickle('combo_set.pkl')

# %%
len(combo_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d95b093f42f7> in <module>()
# ----> 1 len(combo_set)
#
# NameError: name 'combo_set' is not defined

# %%
# skip if using language tool above
# training_set = pd.read_pickle('training_features.pkl')

# %%
# Clean training_set essays before feeding them to the Word2Vec model.
punctuations = string.punctuation

# Define function to cleanup text by removing personal pronouns, stopwords, and puncuation
def cleanup_essays(essays, logging=False):
    texts = []
    counter = 1
    for essay in essays.corrected:
        if counter % 2000 == 0 and logging:
            print("Processed %d out of %d documents." % (counter, len(essays)))
        counter += 1
        essay = nlp(essay, disable=['parser', 'ner'])
        tokens = [tok.lemma_.lower().strip() for tok in essay if tok.lemma_ != '-PRON-']
        tokens = [tok for tok in tokens if tok not in stopwords and tok not in punctuations]
        tokens = ' '.join(tokens)
        texts.append(tokens)
    return pd.Series(texts)

# %%
# Cleanup text and make sure it retains original shape
print('Original training data shape: ', training_set['corrected'].shape)
train_cleaned = cleanup_essays(training_set, logging=True)
print('Cleaned up training data shape: ', train_cleaned.shape)
# Out:
# Original training data shape:  (12976,)
# Processed 2000 out of 12976 documents.
# Processed 4000 out of 12976 documents.
# Processed 6000 out of 12976 documents.
# Processed 8000 out of 12976 documents.
# Processed 10000 out of 12976 documents.
# Processed 12000 out of 12976 documents.
# Cleaned up training data shape:  (12976,)

# %%
# Define function to preprocess text for a word2vec model
def cleanup_essay_word2vec(essays, logging=False):
    sentences = []
    counter = 1
    for essay in essays:
        if counter % 2000 == 0 and logging:
            print("Processed %d out of %d documents" % (counter, len(essays)))
        # Disable tagger so that lemma_ of personal pronouns (I, me, etc) don't getted marked as "-PRON-"
        essay = nlp(essay, disable=['tagger'])
        # Grab lemmatized form of words and make lowercase
        essay = " ".join([tok.lemma_.lower() for tok in essay])
        # Split into sentences based on punctuation
        essay = re.split("[\.?!;] ", essay)
        # Remove commas, periods, and other punctuation (mostly commas)
        essay = [re.sub("[\.,;:!?]", "", sent) for sent in essay]
        # Split into words
        essay = [sent.split() for sent in essay]
        sentences += essay
        counter += 1
    return sentences

# %%
cleaned_word2vec = cleanup_essay_word2vec(combo_set['corrected'], logging=True)
print('Cleaned up training data size (i.e. number of sentences): ', len(cleaned_word2vec))
# Out:
# Processed 2000 out of 21448 documents
# Processed 4000 out of 21448 documents
# Processed 6000 out of 21448 documents
# Processed 8000 out of 21448 documents
# Processed 10000 out of 21448 documents
# Processed 12000 out of 21448 documents
# Processed 14000 out of 21448 documents
# Processed 16000 out of 21448 documents
# Processed 18000 out of 21448 documents
# Processed 20000 out of 21448 documents
# Cleaned up training data size (i.e. number of sentences):  284884

# %%
text_dim = 300
print("Training Word2Vec model...")
wordvec_model = Word2Vec(cleaned_word2vec, size=text_dim, window=5, min_count=3, workers=4, sg=1)
print("Word2Vec model created.")
print("%d unique words represented by %d dimensional vectors" % (len(wordvec_model.wv.vocab), text_dim))
wordvec_model.save('wordvec_model')
print("Word2Vec model saved.")
# Out:
# Training Word2Vec model...
# Word2Vec model created.
# 10352 unique words represented by 300 dimensional vectors

# %%
# Define function to create word vectors given a cleaned piece of text.
def create_average_vec(essay):
    average = np.zeros((text_dim,), dtype='float32')
    num_words = 0.
    for word in essay.split():
        if word in wordvec_model.wv.vocab:
            average = np.add(average, wordvec_model.wv[word])
            num_words += 1.
    if num_words != 0.:
        average = np.divide(average, num_words)
    return average

# %%
# Create word vectors
cleaned_vec = np.zeros((training_set.shape[0], text_dim), dtype="float32")  
for i in range(len(train_cleaned)):
    cleaned_vec[i] = create_average_vec(train_cleaned[i])

print("Word vectors for all essays in the training data set are of shape:", cleaned_vec.shape)
# Out:
# Train word vector shape: (12976, 300)

# %%
# Read generated features from file:
additional_features = pd.read_pickle('training_features.pkl')

# Use select features from Gini feature importances
feature_list = [
                'word_count',
                'corrections',
                'similarity',
                'token_count',
                'unique_token_count',
                'nostop_count',
                'sent_count',
                'ner_count',
                'comma',
                'question',
                'exclamation',
                'quotation',
                'organization',
                'caps',
                'person',
                'location',
                'money',
                'time',
                'date',
                'percent',
                'noun',
                'adj',
                'pron',
                'verb',
                'cconj',
                'adv',
                'det',
                'propn',
                'num',
                'part',
                'intj'
                ]

additional_features = additional_features[feature_list]

stdscaler = StandardScaler()
additional_features = stdscaler.fit_transform(additional_features)
additional_features.shape
# Out:
# (12976, 31)

# %%
# Combine topic number, target score, additional features and cleaned word vectors
all_data = pd.concat([training_set[['topic','target_score']], pd.DataFrame(additional_features), pd.DataFrame(cleaned_vec)], axis=1)
all_data.shape
# Out:
# (12976, 333)

# %% [markdown]
# ## Pass each topic individually through neural network

# %%
# Build model
output_dim = 1
input_dim = all_data.shape[1]-2
dropout = 0.2

model = None
model = Sequential()

# Densely Connected Neural Network (Multi-Layer Perceptron)
model.add(Dense(14, activation='relu', kernel_initializer='he_normal', input_dim=input_dim)) 
model.add(Dropout(dropout))
# model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
# model.add(Dropout(dropout))
model.add(Dense(output_dim))
model.summary()

# Compile the model
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=adam, loss='mse', metrics=['mse','mae'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_176 (Dense)            (None, 14)                4648
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 14)                0
# _________________________________________________________________
# dense_177 (Dense)            (None, 1)                 15
# =================================================================
# Total params: 4,663
# Trainable params: 4,663
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Run each topic individually through neural network
kappa_list = []
weights = []
epochs = 100

for topic in range(1,9):
    # split data
    X = all_data[all_data.topic == topic].drop(['topic', 'target_score'], axis=1)
    y = all_data[all_data.topic == topic].target_score.to_frame()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=26)
    estimator = model.fit(X_train, y_train,
#                       validation_split=0.3,
                      epochs=epochs, batch_size=15, verbose=0)
    # get predictions
    y_pred = pd.DataFrame(model.predict(X_test).reshape(-1))
    
    # get topic kappa score
    kappa_list.append(kappa(y_test.values, y_pred.round(0).astype(int).values, weights='quadratic'))

    # get weights (number of essays)
    weights.append(y_test.shape[0]/all_data.shape[0])    

# get weighted average kappa
qwk = mean_quadratic_weighted_kappa(kappa_list, weights=1) # weights)
print('Combined Kappa score: {:.2f}%'.format(qwk * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-567-524dafe5bbd8> in <module>()
#       8     X = all_data[all_data.topic == topic].drop(['topic', 'target_score'], axis=1)
#       9     y = all_data[all_data.topic == topic].target_score.to_frame()
# ---> 10     estimator = KerasRegressor(build_fn=model, epochs=10, batch_size=55, verbose=0)
#      11     results = cross_val_score(estimator, X, Y, cv=5)
#      12     print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))    # evaluate on model
#
# NameError: name 'KerasRegressor' is not defined

# %%
# Cross-validation

kappa_dict = {}

for topic in range(1,9):
    
    model = None
    # create model
    model = Sequential()
    model.add(Dense(14, input_dim=input_dim, kernel_initializer='he_normal', activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')

    X = all_data[all_data.topic == topic].drop(['topic', 'target_score'], axis=1)
    y = all_data[all_data.topic == topic].target_score.to_frame()
    # split data
    kf = KFold(n_splits=5, random_state=26)
    kappa_list = []
    for train, test in kf.split(X):
        X_train, X_test = X.iloc[train], X.iloc[test]
        y_train, y_test = y.iloc[train], y.iloc[test]
        model.fit(X_train, y_train, epochs=200, batch_size=15, verbose=0) 
        y_pred = pd.DataFrame(model.predict(X_test).reshape(-1))
        kappa_list.append(kappa(y_pred.round(0).astype(int).values, 
                        y.iloc[test].values, 
                        weights='quadratic'))
    print("Kappa for topic", topic, ": {:.3f}%".format(np.mean(kappa_list)))
    kappa_dict[topic] = np.mean(kappa_list)

mqwk = mean_quadratic_weighted_kappa(list(kappa_dict.values()), weights=1) # weights)
print('Combined Kappa score: {:.4f}%'.format(mqwk))
# Out:
# {1: 0.8464197644661671,
#  2: 0.72265734517832,
#  3: 0.7042691068775828,
#  4: 0.7848854314258535,
#  5: 0.827099253962843,
#  6: 0.8183220561528202,
#  7: 0.7923043190208868,
#  8: 0.741857544992065}

# %% [markdown]
# Weighted mean kappa score: 0.7844

# %%
kappa_list
# Out:
# [0.7950615560054923,
#  0.6714273197231228,
#  0.6483337150710032,
#  0.752235935246033,
#  0.8001370910337191,
#  0.8136243314785803,
#  0.7320347290383868,
#  0.6652552883422842]

# %% [markdown]
# ## Combine all topics

# %%
# DataFrame used to pass original values through train_test_split
scores = all_data[['topic', 'target_score']].reset_index() 

# Rescale target_score (essay grades) in range 0 - 60:
scaler = MinMaxScaler((0,60))

# Use this for classification:
# ohe = OneHotEncoder(n_values=61)

# %%
# Rescale and assign target variable y
scaled = []
for topic in range(1,9):
    topic_scores = scores[scores['topic'] == topic]['target_score'].to_frame()
    s = (scaler.fit_transform(topic_scores).reshape(-1))
    scaled = np.append(scaled, s)
    
scores['scaled'] = scaled

"""Use this for classification"""
# Caution: using pd.get_dummies might return the wrong number of unique values
# y = ohe.fit_transform(scores.scaled.to_frame()) # y = pd.get_dummies(scores.scaled)
# print('Number of unique scores after scaling:', unique_scores)
# y.shape

"""Use this for regression"""
y = scores['scaled'].to_frame()

# Features
X = all_data.drop(['topic', 'target_score'], axis=1)

# %% [markdown]
# The histogram of scaled target scores shows a discontinuity due to score expansion, but otherwise acceptable balance.

# %%
# score histogram

y.hist(bins=61)
plt.title('Histogram of scaled target scores')
plt.xlabel('target score')
plt.ylabel('count')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Data to be split
X_train, X_test, y_train, y_test, scores_train, scores_test = \
        train_test_split(
                X, 
                y, 
                scores,
                test_size=0.2, 
                random_state=26
                )

print('X_train size: {}'.format(X_train.shape))
print('X_test size: {}'.format(X_test.shape))
print('y_train size: {}'.format(y_train.shape))
print('y_test size: {}'.format(y_test.shape))
print('scores_train size: {}'.format(scores_train.shape))
print('scores_test size: {}'.format(scores_test.shape))
# Out:
# X_train size: (10380, 330)
# X_test size: (2596, 330)
# y_train size: (10380, 1)
# y_test size: (2596, 1)
# scores_train size: (10380, 4)
# scores_test size: (2596, 4)

# %%
output_dim = y.shape[1]
input_dim = X.shape[1]
dropout = 0.2

def build_model(architecture='mlp'):
    model = Sequential()
    if architecture == 'mlp':
        # Densely Connected Neural Network (Multi-Layer Perceptron)
        model.add(Dense(14, activation='relu', kernel_initializer='he_normal', input_dim=input_dim)) 
        model.add(Dropout(dropout))

# Classification:
#         model.add(Dense(output_dim, activation='softmax'))

# Regression:
        model.add(Dense(output_dim))
    elif architecture == 'cnn':
        # 1-D Convolutional Neural Network
        inputs = Input(shape=(input_dim,1))

        x = Conv1D(64, 3, strides=1, padding='same', activation='relu')(inputs)

        #Cuts the size of the output in half, maxing over every 2 inputs
        x = MaxPooling1D(pool_size=2)(x)
        x = Conv1D(128, 3, strides=1, padding='same', activation='relu')(x)
        x = GlobalMaxPooling1D()(x) 
        outputs = Dense(output_dim, activation='softmax')(x)

        model = Model(inputs=inputs, outputs=outputs, name='CNN')
    elif architecture == 'lstm':
        # LSTM network
        inputs = Input(shape=(input_dim,1))

        x = Bidirectional(LSTM(64, return_sequences=True),
                          merge_mode='concat')(inputs)
        x = Dropout(dropout)(x)
        x = Flatten()(x)
        outputs = Dense(output_dim, activation='softmax')(x)

        model = Model(inputs=inputs, outputs=outputs, name='LSTM')
    else:
        print('Error: Model type not found.')
    return model

# %%
# Define keras model
model = None
# Using MLP in kernel for speed
model = build_model('mlp')
# model = build_model('cnn')
# model = build_model('lstm')

# If the model is a CNN then expand the dimensions of the training data
if model.name == "CNN" or model.name == "LSTM":
    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    print('Text train shape: ', X_train.shape)
    print('Text test shape: ', X_test.shape)
    
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_142 (Dense)            (None, 14)                4634
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 14)                0
# _________________________________________________________________
# dense_143 (Dense)            (None, 1)                 15
# =================================================================
# Total params: 4,649
# Trainable params: 4,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
# Optimizer
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# Classification:
# model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['acc'])

# Regression:
model.compile(optimizer=adam, loss='mse', metrics=['mse','mae'])

# %%
# Define number of epochs
epochs = 100

# Fit the model to the training data
estimator = model.fit(X_train, y_train,
#                       validation_split=0.3,
                      epochs=epochs, batch_size=15, verbose=0)
# Out:
# Epoch 1/100
# 10380/10380 [==============================] - ETA: 14:59 - loss: 2025.0513 - mean_squared_error: 2025.0513 - mean_absolute_error: 41.87 - ETA: 57s - loss: 1516.3525 - mean_squared_error: 1516.3525 - mean_absolute_error: 36.1495 - ETA: 18s - loss: 1441.2828 - mean_squared_error: 1441.2828 - mean_absolute_error: 35.32 - ETA: 11s - loss: 1455.9844 - mean_squared_error: 1455.9844 - mean_absolute_error: 35.44 - ETA: 7s - loss: 1450.7923 - mean_squared_error: 1450.7923 - mean_absolute_error: 35.3825 - ETA: 6s - loss: 1432.3557 - mean_squared_error: 1432.3557 - mean_absolute_error: 35.080 - ETA: 4s - loss: 1419.9537 - mean_squared_error: 1419.9537 - mean_absolute_error: 34.876 - ETA: 4s - loss: 1415.9611 - mean_squared_error: 1415.9611 - mean_absolute_error: 34.806 - ETA: 3s - loss: 1418.4599 - mean_squared_error: 1418.4599 - mean_absolute_error: 34.852 - ETA: 2s - loss: 1414.1464 - mean_squared_error: 1414.1464 - mean_absolute_error: 34.791 - ETA: 2s - loss: 1407.1049 - mean_squared_error: 1407.1049 - mean_absolute_error: 34.668 - ETA: 2s - loss: 1402.8169 - mean_squared_error: 1402.8169 - mean_absolute_error: 34.633 - ETA: 1s - loss: 1394.7162 - mean_squared_error: 1394.7162 - mean_absolute_error: 34.551 - ETA: 1s - loss: 1390.9486 - mean_squared_error: 1390.9486 - mean_absolute_error: 34.495 - ETA: 1s - loss: 1387.8042 - mean_squared_error: 1387.8042 - mean_absolute_error: 34.453 - ETA: 1s - loss: 1380.0233 - mean_squared_error: 1380.0233 - mean_absolute_error: 34.338 - ETA: 1s - loss: 1380.9355 - mean_squared_error: 1380.9355 - mean_absolute_error: 34.350 - ETA: 0s - loss: 1372.5259 - mean_squared_error: 1372.5259 - mean_absolute_error: 34.230 - ETA: 0s - loss: 1363.5192 - mean_squared_error: 1363.5192 - mean_absolute_error: 34.104 - ETA: 0s - loss: 1361.7042 - mean_squared_error: 1361.7042 - mean_absolute_error: 34.076 - ETA: 0s - loss: 1353.8068 - mean_squared_error: 1353.8068 - mean_absolute_error: 33.967 - ETA: 0s - loss: 1349.2103 - mean_squared_error: 1349.2103 - mean_absolute_error: 33.905 - ETA: 0s - loss: 1343.1506 - mean_squared_error: 1343.1506 - mean_absolute_error: 33.821 - ETA: 0s - loss: 1335.7207 - mean_squared_error: 1335.7207 - mean_absolute_error: 33.709 - 3s 246us/step - loss: 1327.3846 - mean_squared_error: 1327.3846 - mean_absolute_error: 33.5866
# Epoch 2/100
# 10380/10380 [==============================] - ETA: 2s - loss: 1350.5945 - mean_squared_error: 1350.5945 - mean_absolute_error: 33.395 - ETA: 1s - loss: 1198.7339 - mean_squared_error: 1198.7339 - mean_absolute_error: 31.917 - ETA: 1s - loss: 1151.7322 - mean_squared_error: 1151.7322 - mean_absolute_error: 31.154 - ETA: 1s - loss: 1136.6189 - mean_squared_error: 1136.6189 - mean_absolute_error: 30.891 - ETA: 1s - loss: 1152.3372 - mean_squared_error: 1152.3372 - mean_absolute_error: 31.115 - ETA: 0s - loss: 1148.5638 - mean_squared_error: 1148.5638 - mean_absolute_error: 30.983 - ETA: 0s - loss: 1137.2742 - mean_squared_error: 1137.2742 - mean_absolute_error: 30.832 - ETA: 0s - loss: 1131.8474 - mean_squared_error: 1131.8474 - mean_absolute_error: 30.738 - ETA: 0s - loss: 1125.5620 - mean_squared_error: 1125.5620 - mean_absolute_error: 30.671 - ETA: 0s - loss: 1119.9734 - mean_squared_error: 1119.9734 - mean_absolute_error: 30.596 - ETA: 0s - loss: 1116.5276 - mean_squared_error: 1116.5276 - mean_absolute_error: 30.559 - ETA: 0s - loss: 1105.8420 - mean_squared_error: 1105.8420 - mean_absolute_error: 30.389 - ETA: 0s - loss: 1092.3784 - mean_squared_error: 1092.3784 - mean_absolute_error: 30.175 - ETA: 0s - loss: 1082.2936 - mean_squared_error: 1082.2936 - mean_absolute_error: 30.005 - ETA: 0s - loss: 1073.7415 - mean_squared_error: 1073.7415 - mean_absolute_error: 29.841 - ETA: 0s - loss: 1062.6592 - mean_squared_error: 1062.6592 - mean_absolute_error: 29.674 - ETA: 0s - loss: 1051.5153 - mean_squared_error: 1051.5153 - mean_absolute_error: 29.494 - ETA: 0s - loss: 1040.2962 - mean_squared_error: 1040.2962 - mean_absolute_error: 29.308 - ETA: 0s - loss: 1035.6485 - mean_squared_error: 1035.6485 - mean_absolute_error: 29.220 - ETA: 0s - loss: 1030.0418 - mean_squared_error: 1030.0418 - mean_absolute_error: 29.123 - ETA: 0s - loss: 1019.0602 - mean_squared_error: 1019.0602 - mean_absolute_error: 28.943 - ETA: 0s - loss: 1011.9911 - mean_squared_error: 1011.9911 - mean_absolute_error: 28.822 - ETA: 0s - loss: 1004.2090 - mean_squared_error: 1004.2090 - mean_absolute_error: 28.709 - 1s 116us/step - loss: 999.9726 - mean_squared_error: 999.9726 - mean_absolute_error: 28.6416
# Epoch 3/100
# 10380/10380 [==============================] - ETA: 2s - loss: 840.9818 - mean_squared_error: 840.9818 - mean_absolute_error: 24.401 - ETA: 1s - loss: 829.9268 - mean_squared_error: 829.9268 - mean_absolute_error: 25.565 - ETA: 1s - loss: 777.7048 - mean_squared_error: 777.7048 - mean_absolute_error: 24.754 - ETA: 1s - loss: 769.9039 - mean_squared_error: 769.9039 - mean_absolute_error: 24.656 - ETA: 1s - loss: 775.0062 - mean_squared_error: 775.0062 - mean_absolute_error: 24.745 - ETA: 1s - loss: 769.0186 - mean_squared_error: 769.0186 - mean_absolute_error: 24.612 - ETA: 0s - loss: 757.8345 - mean_squared_error: 757.8345 - mean_absolute_error: 24.405 - ETA: 0s - loss: 758.6354 - mean_squared_error: 758.6354 - mean_absolute_error: 24.452 - ETA: 0s - loss: 748.6918 - mean_squared_error: 748.6918 - mean_absolute_error: 24.249 - ETA: 0s - loss: 739.9997 - mean_squared_error: 739.9997 - mean_absolute_error: 24.101 - ETA: 0s - loss: 737.1406 - mean_squared_error: 737.1406 - mean_absolute_error: 24.036 - ETA: 0s - loss: 733.6297 - mean_squared_error: 733.6297 - mean_absolute_error: 23.955 - ETA: 0s - loss: 727.1255 - mean_squared_error: 727.1255 - mean_absolute_error: 23.817 - ETA: 0s - loss: 723.0399 - mean_squared_error: 723.0399 - mean_absolute_error: 23.708 - ETA: 0s - loss: 718.2038 - mean_squared_error: 718.2038 - mean_absolute_error: 23.605 - ETA: 0s - loss: 713.9892 - mean_squared_error: 713.9892 - mean_absolute_error: 23.526 - ETA: 0s - loss: 708.9754 - mean_squared_error: 708.9754 - mean_absolute_error: 23.421 - ETA: 0s - loss: 702.1201 - mean_squared_error: 702.1201 - mean_absolute_error: 23.278 - ETA: 0s - loss: 696.9440 - mean_squared_error: 696.9440 - mean_absolute_error: 23.158 - ETA: 0s - loss: 689.1600 - mean_squared_error: 689.1600 - mean_absolute_error: 22.995 - ETA: 0s - loss: 681.4805 - mean_squared_error: 681.4805 - mean_absolute_error: 22.837 - ETA: 0s - loss: 675.7378 - mean_squared_error: 675.7378 - mean_absolute_error: 22.707 - ETA: 0s - loss: 671.2373 - mean_squared_error: 671.2373 - mean_absolute_error: 22.608 - ETA: 0s - loss: 667.2138 - mean_squared_error: 667.2138 - mean_absolute_error: 22.526 - ETA: 0s - loss: 661.6302 - mean_squared_error: 661.6302 - mean_absolute_error: 22.405 - 1s 121us/step - loss: 661.1958 - mean_squared_error: 661.1958 - mean_absolute_error: 22.3961
# Epoch 4/100
# 10380/10380 [==============================] - ETA: 2s - loss: 406.3759 - mean_squared_error: 406.3759 - mean_absolute_error: 17.656 - ETA: 1s - loss: 502.5891 - mean_squared_error: 502.5891 - mean_absolute_error: 19.182 - ETA: 1s - loss: 526.1300 - mean_squared_error: 526.1300 - mean_absolute_error: 19.548 - ETA: 1s - loss: 490.8921 - mean_squared_error: 490.8921 - mean_absolute_error: 18.739 - ETA: 1s - loss: 496.3482 - mean_squared_error: 496.3482 - mean_absolute_error: 18.820 - ETA: 1s - loss: 489.9770 - mean_squared_error: 489.9770 - mean_absolute_error: 18.692 - ETA: 0s - loss: 475.0741 - mean_squared_error: 475.0741 - mean_absolute_error: 18.336 - ETA: 0s - loss: 472.1280 - mean_squared_error: 472.1280 - mean_absolute_error: 18.236 - ETA: 0s - loss: 465.7788 - mean_squared_error: 465.7788 - mean_absolute_error: 18.066 - ETA: 0s - loss: 461.1580 - mean_squared_error: 461.1580 - mean_absolute_error: 17.978 - ETA: 0s - loss: 457.0782 - mean_squared_error: 457.0782 - mean_absolute_error: 17.866 - ETA: 0s - loss: 451.0292 - mean_squared_error: 451.0292 - mean_absolute_error: 17.732 - ETA: 0s - loss: 444.9185 - mean_squared_error: 444.9185 - mean_absolute_error: 17.588 - ETA: 0s - loss: 438.6965 - mean_squared_error: 438.6965 - mean_absolute_error: 17.436 - ETA: 0s - loss: 434.4996 - mean_squared_error: 434.4996 - mean_absolute_error: 17.357 - ETA: 0s - loss: 432.2970 - mean_squared_error: 432.2970 - mean_absolute_error: 17.303 - ETA: 0s - loss: 433.0133 - mean_squared_error: 433.0133 - mean_absolute_error: 17.318 - ETA: 0s - loss: 429.5033 - mean_squared_error: 429.5033 - mean_absolute_error: 17.225 - ETA: 0s - loss: 427.8813 - mean_squared_error: 427.8813 - mean_absolute_error: 17.180 - ETA: 0s - loss: 423.3616 - mean_squared_error: 423.3616 - mean_absolute_error: 17.066 - ETA: 0s - loss: 420.4191 - mean_squared_error: 420.4191 - mean_absolute_error: 16.988 - ETA: 0s - loss: 416.9518 - mean_squared_error: 416.9518 - mean_absolute_error: 16.899 - ETA: 0s - loss: 411.5055 - mean_squared_error: 411.5055 - mean_absolute_error: 16.757 - ETA: 0s - loss: 406.6893 - mean_squared_error: 406.6893 - mean_absolute_error: 16.650 - 1s 119us/step - loss: 404.3053 - mean_squared_error: 404.3053 - mean_absolute_error: 16.5932
# Epoch 5/100
# 10380/10380 [==============================] - ETA: 2s - loss: 240.6170 - mean_squared_error: 240.6170 - mean_absolute_error: 11.976 - ETA: 1s - loss: 297.9456 - mean_squared_error: 297.9456 - mean_absolute_error: 13.668 - ETA: 1s - loss: 311.1869 - mean_squared_error: 311.1869 - mean_absolute_error: 14.111 - ETA: 1s - loss: 314.1172 - mean_squared_error: 314.1172 - mean_absolute_error: 14.138 - ETA: 1s - loss: 306.3016 - mean_squared_error: 306.3016 - mean_absolute_error: 14.059 - ETA: 0s - loss: 307.0073 - mean_squared_error: 307.0073 - mean_absolute_error: 14.072 - ETA: 0s - loss: 305.9855 - mean_squared_error: 305.9855 - mean_absolute_error: 14.066 - ETA: 0s - loss: 303.2501 - mean_squared_error: 303.2501 - mean_absolute_error: 13.988 - ETA: 0s - loss: 296.3530 - mean_squared_error: 296.3530 - mean_absolute_error: 13.837 - ETA: 0s - loss: 293.0334 - mean_squared_error: 293.0334 - mean_absolute_error: 13.743 - ETA: 0s - loss: 288.0601 - mean_squared_error: 288.0601 - mean_absolute_error: 13.611 - ETA: 0s - loss: 285.0908 - mean_squared_error: 285.0908 - mean_absolute_error: 13.537 - ETA: 0s - loss: 285.0861 - mean_squared_error: 285.0861 - mean_absolute_error: 13.540 - ETA: 0s - loss: 282.3244 - mean_squared_error: 282.3244 - mean_absolute_error: 13.448 - ETA: 0s - loss: 281.2581 - mean_squared_error: 281.2581 - mean_absolute_error: 13.421 - ETA: 0s - loss: 280.0212 - mean_squared_error: 280.0212 - mean_absolute_error: 13.402 - ETA: 0s - loss: 277.4563 - mean_squared_error: 277.4563 - mean_absolute_error: 13.323 - ETA: 0s - loss: 276.4982 - mean_squared_error: 276.4982 - mean_absolute_error: 13.307 - ETA: 0s - loss: 276.1698 - mean_squared_error: 276.1698 - mean_absolute_error: 13.314 - ETA: 0s - loss: 272.6388 - mean_squared_error: 272.6388 - mean_absolute_error: 13.218 - ETA: 0s - loss: 271.1763 - mean_squared_error: 271.1763 - mean_absolute_error: 13.183 - ETA: 0s - loss: 271.5113 - mean_squared_error: 271.5113 - mean_absolute_error: 13.173 - ETA: 0s - loss: 269.3022 - mean_squared_error: 269.3022 - mean_absolute_error: 13.116 - ETA: 0s - loss: 268.5398 - mean_squared_error: 268.5398 - mean_absolute_error: 13.099 - 1s 119us/step - loss: 267.7678 - mean_squared_error: 267.7678 - mean_absolute_error: 13.0735
# Epoch 6/100
# 10380/10380 [==============================] - ETA: 2s - loss: 339.0820 - mean_squared_error: 339.0820 - mean_absolute_error: 13.576 - ETA: 1s - loss: 244.4730 - mean_squared_error: 244.4730 - mean_absolute_error: 12.486 - ETA: 1s - loss: 225.2374 - mean_squared_error: 225.2374 - mean_absolute_error: 11.994 - ETA: 1s - loss: 227.9316 - mean_squared_error: 227.9316 - mean_absolute_error: 12.006 - ETA: 1s - loss: 228.8314 - mean_squared_error: 228.8314 - mean_absolute_error: 12.065 - ETA: 0s - loss: 230.3185 - mean_squared_error: 230.3185 - mean_absolute_error: 12.118 - ETA: 0s - loss: 225.8083 - mean_squared_error: 225.8083 - mean_absolute_error: 12.023 - ETA: 0s - loss: 223.8618 - mean_squared_error: 223.8618 - mean_absolute_error: 11.970 - ETA: 0s - loss: 223.2016 - mean_squared_error: 223.2016 - mean_absolute_error: 11.935 - ETA: 0s - loss: 223.0658 - mean_squared_error: 223.0658 - mean_absolute_error: 11.914 - ETA: 0s - loss: 221.1647 - mean_squared_error: 221.1647 - mean_absolute_error: 11.854 - ETA: 0s - loss: 220.5853 - mean_squared_error: 220.5853 - mean_absolute_error: 11.796 - ETA: 0s - loss: 220.5195 - mean_squared_error: 220.5195 - mean_absolute_error: 11.803 - ETA: 0s - loss: 220.1218 - mean_squared_error: 220.1218 - mean_absolute_error: 11.792 - ETA: 0s - loss: 221.5318 - mean_squared_error: 221.5318 - mean_absolute_error: 11.826 - ETA: 0s - loss: 221.1410 - mean_squared_error: 221.1410 - mean_absolute_error: 11.816 - ETA: 0s - loss: 219.3488 - mean_squared_error: 219.3488 - mean_absolute_error: 11.757 - ETA: 0s - loss: 218.7912 - mean_squared_error: 218.7912 - mean_absolute_error: 11.740 - ETA: 0s - loss: 218.1660 - mean_squared_error: 218.1660 - mean_absolute_error: 11.725 - ETA: 0s - loss: 218.7152 - mean_squared_error: 218.7152 - mean_absolute_error: 11.736 - ETA: 0s - loss: 218.9541 - mean_squared_error: 218.9541 - mean_absolute_error: 11.737 - ETA: 0s - loss: 219.6208 - mean_squared_error: 219.6208 - mean_absolute_error: 11.750 - ETA: 0s - loss: 219.2909 - mean_squared_error: 219.2909 - mean_absolute_error: 11.743 - ETA: 0s - loss: 219.4401 - mean_squared_error: 219.4401 - mean_absolute_error: 11.750 - 1s 121us/step - loss: 218.9910 - mean_squared_error: 218.9910 - mean_absolute_error: 11.7458
# Epoch 7/100
# 10380/10380 [==============================] - ETA: 0s - loss: 390.7852 - mean_squared_error: 390.7852 - mean_absolute_error: 15.414 - ETA: 1s - loss: 207.9380 - mean_squared_error: 207.9380 - mean_absolute_error: 11.430 - ETA: 1s - loss: 219.2322 - mean_squared_error: 219.2322 - mean_absolute_error: 11.778 - ETA: 1s - loss: 209.9734 - mean_squared_error: 209.9734 - mean_absolute_error: 11.429 - ETA: 0s - loss: 209.8181 - mean_squared_error: 209.8181 - mean_absolute_error: 11.477 - ETA: 0s - loss: 211.9455 - mean_squared_error: 211.9455 - mean_absolute_error: 11.506 - ETA: 0s - loss: 209.8986 - mean_squared_error: 209.8986 - mean_absolute_error: 11.439 - ETA: 0s - loss: 208.0766 - mean_squared_error: 208.0766 - mean_absolute_error: 11.408 - ETA: 0s - loss: 209.0896 - mean_squared_error: 209.0896 - mean_absolute_error: 11.440 - ETA: 0s - loss: 210.6804 - mean_squared_error: 210.6804 - mean_absolute_error: 11.509 - ETA: 0s - loss: 210.7626 - mean_squared_error: 210.7626 - mean_absolute_error: 11.526 - ETA: 0s - loss: 210.3412 - mean_squared_error: 210.3412 - mean_absolute_error: 11.510 - ETA: 0s - loss: 210.0878 - mean_squared_error: 210.0878 - mean_absolute_error: 11.495 - ETA: 0s - loss: 208.7554 - mean_squared_error: 208.7554 - mean_absolute_error: 11.468 - ETA: 0s - loss: 208.3378 - mean_squared_error: 208.3378 - mean_absolute_error: 11.468 - ETA: 0s - loss: 208.6232 - mean_squared_error: 208.6232 - mean_absolute_error: 11.475 - ETA: 0s - loss: 208.2168 - mean_squared_error: 208.2168 - mean_absolute_error: 11.461 - ETA: 0s - loss: 208.3178 - mean_squared_error: 208.3178 - mean_absolute_error: 11.462 - ETA: 0s - loss: 208.4078 - mean_squared_error: 208.4078 - mean_absolute_error: 11.465 - ETA: 0s - loss: 207.5521 - mean_squared_error: 207.5521 - mean_absolute_error: 11.452 - ETA: 0s - loss: 208.7470 - mean_squared_error: 208.7470 - mean_absolute_error: 11.486 - ETA: 0s - loss: 208.5690 - mean_squared_error: 208.5690 - mean_absolute_error: 11.482 - ETA: 0s - loss: 207.8685 - mean_squared_error: 207.8685 - mean_absolute_error: 11.457 - 1s 118us/step - loss: 207.4186 - mean_squared_error: 207.4186 - mean_absolute_error: 11.4488
# Epoch 8/100
# 10380/10380 [==============================] - ETA: 2s - loss: 355.5391 - mean_squared_error: 355.5391 - mean_absolute_error: 15.422 - ETA: 1s - loss: 217.4392 - mean_squared_error: 217.4392 - mean_absolute_error: 11.506 - ETA: 1s - loss: 201.3789 - mean_squared_error: 201.3789 - mean_absolute_error: 11.060 - ETA: 1s - loss: 202.9730 - mean_squared_error: 202.9730 - mean_absolute_error: 11.125 - ETA: 1s - loss: 202.1024 - mean_squared_error: 202.1024 - mean_absolute_error: 11.133 - ETA: 0s - loss: 201.3408 - mean_squared_error: 201.3408 - mean_absolute_error: 11.117 - ETA: 0s - loss: 202.0375 - mean_squared_error: 202.0375 - mean_absolute_error: 11.131 - ETA: 0s - loss: 200.0518 - mean_squared_error: 200.0518 - mean_absolute_error: 11.083 - ETA: 0s - loss: 200.1164 - mean_squared_error: 200.1164 - mean_absolute_error: 11.091 - ETA: 0s - loss: 199.4266 - mean_squared_error: 199.4266 - mean_absolute_error: 11.088 - ETA: 0s - loss: 199.5248 - mean_squared_error: 199.5248 - mean_absolute_error: 11.095 - ETA: 0s - loss: 198.7843 - mean_squared_error: 198.7843 - mean_absolute_error: 11.082 - ETA: 0s - loss: 197.7337 - mean_squared_error: 197.7337 - mean_absolute_error: 11.068 - ETA: 0s - loss: 198.2358 - mean_squared_error: 198.2358 - mean_absolute_error: 11.083 - ETA: 0s - loss: 198.7679 - mean_squared_error: 198.7679 - mean_absolute_error: 11.112 - ETA: 0s - loss: 198.1458 - mean_squared_error: 198.1458 - mean_absolute_error: 11.111 - ETA: 0s - loss: 197.9029 - mean_squared_error: 197.9029 - mean_absolute_error: 11.112 - ETA: 0s - loss: 196.5856 - mean_squared_error: 196.5856 - mean_absolute_error: 11.075 - ETA: 0s - loss: 196.8191 - mean_squared_error: 196.8191 - mean_absolute_error: 11.074 - ETA: 0s - loss: 196.9374 - mean_squared_error: 196.9374 - mean_absolute_error: 11.077 - ETA: 0s - loss: 198.1739 - mean_squared_error: 198.1739 - mean_absolute_error: 11.115 - ETA: 0s - loss: 198.0058 - mean_squared_error: 198.0058 - mean_absolute_error: 11.109 - ETA: 0s - loss: 198.0523 - mean_squared_error: 198.0523 - mean_absolute_error: 11.112 - ETA: 0s - loss: 198.8854 - mean_squared_error: 198.8854 - mean_absolute_error: 11.137 - 1s 119us/step - loss: 198.3776 - mean_squared_error: 198.3776 - mean_absolute_error: 11.1265
# Epoch 9/100
# 10380/10380 [==============================] - ETA: 1s - loss: 105.5449 - mean_squared_error: 105.5449 - mean_absolute_error: 8.69 - ETA: 1s - loss: 183.4584 - mean_squared_error: 183.4584 - mean_absolute_error: 10.641 - ETA: 1s - loss: 179.4248 - mean_squared_error: 179.4248 - mean_absolute_error: 10.611 - ETA: 1s - loss: 182.5468 - mean_squared_error: 182.5468 - mean_absolute_error: 10.655 - ETA: 0s - loss: 184.5789 - mean_squared_error: 184.5789 - mean_absolute_error: 10.707 - ETA: 0s - loss: 188.3554 - mean_squared_error: 188.3554 - mean_absolute_error: 10.832 - ETA: 0s - loss: 193.4856 - mean_squared_error: 193.4856 - mean_absolute_error: 10.949 - ETA: 0s - loss: 195.5004 - mean_squared_error: 195.5004 - mean_absolute_error: 11.039 - ETA: 0s - loss: 195.8170 - mean_squared_error: 195.8170 - mean_absolute_error: 11.048 - ETA: 0s - loss: 196.5301 - mean_squared_error: 196.5301 - mean_absolute_error: 11.059 - ETA: 0s - loss: 196.3426 - mean_squared_error: 196.3426 - mean_absolute_error: 11.045 - ETA: 0s - loss: 196.1317 - mean_squared_error: 196.1317 - mean_absolute_error: 11.035 - ETA: 0s - loss: 194.8083 - mean_squared_error: 194.8083 - mean_absolute_error: 10.993 - ETA: 0s - loss: 195.1406 - mean_squared_error: 195.1406 - mean_absolute_error: 11.008 - ETA: 0s - loss: 194.9527 - mean_squared_error: 194.9527 - mean_absolute_error: 11.000 - ETA: 0s - loss: 195.2513 - mean_squared_error: 195.2513 - mean_absolute_error: 11.036 - ETA: 0s - loss: 195.9279 - mean_squared_error: 195.9279 - mean_absolute_error: 11.055 - ETA: 0s - loss: 195.3936 - mean_squared_error: 195.3936 - mean_absolute_error: 11.041 - ETA: 0s - loss: 194.2731 - mean_squared_error: 194.2731 - mean_absolute_error: 11.001 - ETA: 0s - loss: 194.2773 - mean_squared_error: 194.2773 - mean_absolute_error: 11.003 - ETA: 0s - loss: 193.2154 - mean_squared_error: 193.2154 - mean_absolute_error: 10.965 - ETA: 0s - loss: 192.7449 - mean_squared_error: 192.7449 - mean_absolute_error: 10.945 - ETA: 0s - loss: 192.9215 - mean_squared_error: 192.9215 - mean_absolute_error: 10.937 - 1s 117us/step - loss: 192.9976 - mean_squared_error: 192.9976 - mean_absolute_error: 10.9373
# Epoch 10/100
# 10380/10380 [==============================] - ETA: 0s - loss: 209.9401 - mean_squared_error: 209.9401 - mean_absolute_error: 12.383 - ETA: 1s - loss: 193.0308 - mean_squared_error: 193.0308 - mean_absolute_error: 11.012 - ETA: 1s - loss: 198.9209 - mean_squared_error: 198.9209 - mean_absolute_error: 11.147 - ETA: 1s - loss: 197.6222 - mean_squared_error: 197.6222 - mean_absolute_error: 11.076 - ETA: 1s - loss: 194.9258 - mean_squared_error: 194.9258 - mean_absolute_error: 10.983 - ETA: 0s - loss: 192.1386 - mean_squared_error: 192.1386 - mean_absolute_error: 10.903 - ETA: 0s - loss: 191.5813 - mean_squared_error: 191.5813 - mean_absolute_error: 10.900 - ETA: 0s - loss: 189.8641 - mean_squared_error: 189.8641 - mean_absolute_error: 10.884 - ETA: 0s - loss: 189.2083 - mean_squared_error: 189.2083 - mean_absolute_error: 10.874 - ETA: 0s - loss: 187.5678 - mean_squared_error: 187.5678 - mean_absolute_error: 10.808 - ETA: 0s - loss: 188.3067 - mean_squared_error: 188.3067 - mean_absolute_error: 10.831 - ETA: 0s - loss: 188.0216 - mean_squared_error: 188.0216 - mean_absolute_error: 10.835 - ETA: 0s - loss: 189.7056 - mean_squared_error: 189.7056 - mean_absolute_error: 10.895 - ETA: 0s - loss: 189.7485 - mean_squared_error: 189.7485 - mean_absolute_error: 10.906 - ETA: 0s - loss: 190.2453 - mean_squared_error: 190.2453 - mean_absolute_error: 10.914 - ETA: 0s - loss: 189.6873 - mean_squared_error: 189.6873 - mean_absolute_error: 10.909 - ETA: 0s - loss: 189.4049 - mean_squared_error: 189.4049 - mean_absolute_error: 10.887 - ETA: 0s - loss: 188.7150 - mean_squared_error: 188.7150 - mean_absolute_error: 10.859 - ETA: 0s - loss: 189.4937 - mean_squared_error: 189.4937 - mean_absolute_error: 10.887 - ETA: 0s - loss: 188.6613 - mean_squared_error: 188.6613 - mean_absolute_error: 10.857 - ETA: 0s - loss: 188.0348 - mean_squared_error: 188.0348 - mean_absolute_error: 10.838 - ETA: 0s - loss: 188.1133 - mean_squared_error: 188.1133 - mean_absolute_error: 10.842 - ETA: 0s - loss: 188.2551 - mean_squared_error: 188.2551 - mean_absolute_error: 10.837 - ETA: 0s - loss: 187.9629 - mean_squared_error: 187.9629 - mean_absolute_error: 10.821 - 1s 119us/step - loss: 188.3531 - mean_squared_error: 188.3531 - mean_absolute_error: 10.8303
# Epoch 11/100
# 10380/10380 [==============================] - ETA: 2s - loss: 86.6076 - mean_squared_error: 86.6076 - mean_absolute_error: 8.13 - ETA: 1s - loss: 184.6413 - mean_squared_error: 184.6413 - mean_absolute_error: 10.629 - ETA: 1s - loss: 181.7830 - mean_squared_error: 181.7830 - mean_absolute_error: 10.587 - ETA: 1s - loss: 181.9061 - mean_squared_error: 181.9061 - mean_absolute_error: 10.600 - ETA: 1s - loss: 182.2733 - mean_squared_error: 182.2733 - mean_absolute_error: 10.639 - ETA: 0s - loss: 182.6060 - mean_squared_error: 182.6060 - mean_absolute_error: 10.654 - ETA: 0s - loss: 184.2214 - mean_squared_error: 184.2214 - mean_absolute_error: 10.721 - ETA: 0s - loss: 185.1200 - mean_squared_error: 185.1200 - mean_absolute_error: 10.751 - ETA: 0s - loss: 182.8693 - mean_squared_error: 182.8693 - mean_absolute_error: 10.691 - ETA: 0s - loss: 181.9080 - mean_squared_error: 181.9080 - mean_absolute_error: 10.665 - ETA: 0s - loss: 182.6148 - mean_squared_error: 182.6148 - mean_absolute_error: 10.690 - ETA: 0s - loss: 181.4396 - mean_squared_error: 181.4396 - mean_absolute_error: 10.637 - ETA: 0s - loss: 180.8984 - mean_squared_error: 180.8984 - mean_absolute_error: 10.618 - ETA: 0s - loss: 179.3649 - mean_squared_error: 179.3649 - mean_absolute_error: 10.570 - ETA: 0s - loss: 179.0695 - mean_squared_error: 179.0695 - mean_absolute_error: 10.563 - ETA: 0s - loss: 180.2793 - mean_squared_error: 180.2793 - mean_absolute_error: 10.608 - ETA: 0s - loss: 181.0647 - mean_squared_error: 181.0647 - mean_absolute_error: 10.633 - ETA: 0s - loss: 182.2671 - mean_squared_error: 182.2671 - mean_absolute_error: 10.676 - ETA: 0s - loss: 182.7730 - mean_squared_error: 182.7730 - mean_absolute_error: 10.680 - ETA: 0s - loss: 184.0086 - mean_squared_error: 184.0086 - mean_absolute_error: 10.727 - ETA: 0s - loss: 183.7520 - mean_squared_error: 183.7520 - mean_absolute_error: 10.719 - ETA: 0s - loss: 183.6841 - mean_squared_error: 183.6841 - mean_absolute_error: 10.721 - ETA: 0s - loss: 183.2491 - mean_squared_error: 183.2491 - mean_absolute_error: 10.713 - ETA: 0s - loss: 184.4782 - mean_squared_error: 184.4782 - mean_absolute_error: 10.746 - 1s 119us/step - loss: 184.2047 - mean_squared_error: 184.2047 - mean_absolute_error: 10.7372
# Epoch 12/100
# 10380/10380 [==============================] - ETA: 2s - loss: 245.3931 - mean_squared_error: 245.3931 - mean_absolute_error: 11.855 - ETA: 1s - loss: 196.0504 - mean_squared_error: 196.0504 - mean_absolute_error: 10.993 - ETA: 1s - loss: 184.8776 - mean_squared_error: 184.8776 - mean_absolute_error: 10.715 - ETA: 1s - loss: 186.8014 - mean_squared_error: 186.8014 - mean_absolute_error: 10.787 - ETA: 1s - loss: 189.2465 - mean_squared_error: 189.2465 - mean_absolute_error: 10.939 - ETA: 0s - loss: 185.2016 - mean_squared_error: 185.2016 - mean_absolute_error: 10.823 - ETA: 0s - loss: 183.0018 - mean_squared_error: 183.0018 - mean_absolute_error: 10.723 - ETA: 0s - loss: 184.4060 - mean_squared_error: 184.4060 - mean_absolute_error: 10.769 - ETA: 0s - loss: 184.1747 - mean_squared_error: 184.1747 - mean_absolute_error: 10.774 - ETA: 0s - loss: 184.9823 - mean_squared_error: 184.9823 - mean_absolute_error: 10.754 - ETA: 0s - loss: 183.0725 - mean_squared_error: 183.0725 - mean_absolute_error: 10.681 - ETA: 0s - loss: 182.4839 - mean_squared_error: 182.4839 - mean_absolute_error: 10.683 - ETA: 0s - loss: 183.1192 - mean_squared_error: 183.1192 - mean_absolute_error: 10.720 - ETA: 0s - loss: 183.5358 - mean_squared_error: 183.5358 - mean_absolute_error: 10.717 - ETA: 0s - loss: 184.1793 - mean_squared_error: 184.1793 - mean_absolute_error: 10.733 - ETA: 0s - loss: 183.9037 - mean_squared_error: 183.9037 - mean_absolute_error: 10.711 - ETA: 0s - loss: 184.5945 - mean_squared_error: 184.5945 - mean_absolute_error: 10.725 - ETA: 0s - loss: 182.9254 - mean_squared_error: 182.9254 - mean_absolute_error: 10.685 - ETA: 0s - loss: 182.4291 - mean_squared_error: 182.4291 - mean_absolute_error: 10.682 - ETA: 0s - loss: 181.9181 - mean_squared_error: 181.9181 - mean_absolute_error: 10.656 - ETA: 0s - loss: 181.4199 - mean_squared_error: 181.4199 - mean_absolute_error: 10.645 - ETA: 0s - loss: 181.5604 - mean_squared_error: 181.5604 - mean_absolute_error: 10.653 - ETA: 0s - loss: 182.5686 - mean_squared_error: 182.5686 - mean_absolute_error: 10.687 - 1s 118us/step - loss: 182.8589 - mean_squared_error: 182.8589 - mean_absolute_error: 10.6936
# Epoch 13/100
# 10380/10380 [==============================] - ETA: 0s - loss: 198.5048 - mean_squared_error: 198.5048 - mean_absolute_error: 10.346 - ETA: 1s - loss: 204.7376 - mean_squared_error: 204.7376 - mean_absolute_error: 11.369 - ETA: 1s - loss: 185.6339 - mean_squared_error: 185.6339 - mean_absolute_error: 10.786 - ETA: 1s - loss: 176.2286 - mean_squared_error: 176.2286 - mean_absolute_error: 10.488 - ETA: 1s - loss: 177.4646 - mean_squared_error: 177.4646 - mean_absolute_error: 10.521 - ETA: 0s - loss: 174.0629 - mean_squared_error: 174.0629 - mean_absolute_error: 10.367 - ETA: 0s - loss: 171.3164 - mean_squared_error: 171.3164 - mean_absolute_error: 10.259 - ETA: 0s - loss: 172.2665 - mean_squared_error: 172.2665 - mean_absolute_error: 10.265 - ETA: 0s - loss: 173.5760 - mean_squared_error: 173.5760 - mean_absolute_error: 10.323 - ETA: 0s - loss: 173.6813 - mean_squared_error: 173.6813 - mean_absolute_error: 10.323 - ETA: 0s - loss: 172.2349 - mean_squared_error: 172.2349 - mean_absolute_error: 10.262 - ETA: 0s - loss: 173.4801 - mean_squared_error: 173.4801 - mean_absolute_error: 10.303 - ETA: 0s - loss: 174.3531 - mean_squared_error: 174.3531 - mean_absolute_error: 10.352 - ETA: 0s - loss: 175.4073 - mean_squared_error: 175.4073 - mean_absolute_error: 10.401 - ETA: 0s - loss: 173.7904 - mean_squared_error: 173.7904 - mean_absolute_error: 10.348 - ETA: 0s - loss: 174.8341 - mean_squared_error: 174.8341 - mean_absolute_error: 10.390 - ETA: 0s - loss: 177.1484 - mean_squared_error: 177.1484 - mean_absolute_error: 10.457 - ETA: 0s - loss: 177.0830 - mean_squared_error: 177.0830 - mean_absolute_error: 10.460 - ETA: 0s - loss: 176.1189 - mean_squared_error: 176.1189 - mean_absolute_error: 10.437 - ETA: 0s - loss: 175.5611 - mean_squared_error: 175.5611 - mean_absolute_error: 10.425 - ETA: 0s - loss: 175.2172 - mean_squared_error: 175.2172 - mean_absolute_error: 10.410 - ETA: 0s - loss: 174.5998 - mean_squared_error: 174.5998 - mean_absolute_error: 10.406 - ETA: 0s - loss: 174.7044 - mean_squared_error: 174.7044 - mean_absolute_error: 10.405 - ETA: 0s - loss: 175.3979 - mean_squared_error: 175.3979 - mean_absolute_error: 10.434 - 1s 117us/step - loss: 175.5580 - mean_squared_error: 175.5580 - mean_absolute_error: 10.4441
# Epoch 14/100
# 10380/10380 [==============================] - ETA: 2s - loss: 260.4848 - mean_squared_error: 260.4848 - mean_absolute_error: 11.983 - ETA: 1s - loss: 174.1695 - mean_squared_error: 174.1695 - mean_absolute_error: 10.173 - ETA: 1s - loss: 176.6393 - mean_squared_error: 176.6393 - mean_absolute_error: 10.254 - ETA: 1s - loss: 177.9084 - mean_squared_error: 177.9084 - mean_absolute_error: 10.382 - ETA: 0s - loss: 174.8796 - mean_squared_error: 174.8796 - mean_absolute_error: 10.258 - ETA: 0s - loss: 176.5414 - mean_squared_error: 176.5414 - mean_absolute_error: 10.391 - ETA: 0s - loss: 179.8019 - mean_squared_error: 179.8019 - mean_absolute_error: 10.509 - ETA: 0s - loss: 179.0214 - mean_squared_error: 179.0214 - mean_absolute_error: 10.475 - ETA: 0s - loss: 177.2603 - mean_squared_error: 177.2603 - mean_absolute_error: 10.415 - ETA: 0s - loss: 177.6970 - mean_squared_error: 177.6970 - mean_absolute_error: 10.438 - ETA: 0s - loss: 178.2616 - mean_squared_error: 178.2616 - mean_absolute_error: 10.455 - ETA: 0s - loss: 177.5757 - mean_squared_error: 177.5757 - mean_absolute_error: 10.447 - ETA: 0s - loss: 176.7925 - mean_squared_error: 176.7925 - mean_absolute_error: 10.430 - ETA: 0s - loss: 175.6892 - mean_squared_error: 175.6892 - mean_absolute_error: 10.409 - ETA: 0s - loss: 175.2134 - mean_squared_error: 175.2134 - mean_absolute_error: 10.403 - ETA: 0s - loss: 175.1962 - mean_squared_error: 175.1962 - mean_absolute_error: 10.411 - ETA: 0s - loss: 175.5990 - mean_squared_error: 175.5990 - mean_absolute_error: 10.424 - ETA: 0s - loss: 175.2124 - mean_squared_error: 175.2124 - mean_absolute_error: 10.416 - ETA: 0s - loss: 174.8439 - mean_squared_error: 174.8439 - mean_absolute_error: 10.413 - ETA: 0s - loss: 175.1658 - mean_squared_error: 175.1658 - mean_absolute_error: 10.424 - ETA: 0s - loss: 174.1619 - mean_squared_error: 174.1619 - mean_absolute_error: 10.389 - ETA: 0s - loss: 174.1630 - mean_squared_error: 174.1630 - mean_absolute_error: 10.393 - ETA: 0s - loss: 173.7461 - mean_squared_error: 173.7461 - mean_absolute_error: 10.381 - 1s 118us/step - loss: 173.6596 - mean_squared_error: 173.6596 - mean_absolute_error: 10.3884
# Epoch 15/100
# 10380/10380 [==============================] - ETA: 2s - loss: 229.4659 - mean_squared_error: 229.4659 - mean_absolute_error: 12.251 - ETA: 1s - loss: 179.3707 - mean_squared_error: 179.3707 - mean_absolute_error: 10.487 - ETA: 1s - loss: 179.1458 - mean_squared_error: 179.1458 - mean_absolute_error: 10.569 - ETA: 1s - loss: 169.6161 - mean_squared_error: 169.6161 - mean_absolute_error: 10.263 - ETA: 1s - loss: 171.8590 - mean_squared_error: 171.8590 - mean_absolute_error: 10.381 - ETA: 0s - loss: 175.3069 - mean_squared_error: 175.3069 - mean_absolute_error: 10.428 - ETA: 0s - loss: 174.3904 - mean_squared_error: 174.3904 - mean_absolute_error: 10.424 - ETA: 0s - loss: 172.6971 - mean_squared_error: 172.6971 - mean_absolute_error: 10.373 - ETA: 0s - loss: 168.6471 - mean_squared_error: 168.6471 - mean_absolute_error: 10.261 - ETA: 0s - loss: 168.8728 - mean_squared_error: 168.8728 - mean_absolute_error: 10.284 - ETA: 0s - loss: 169.6039 - mean_squared_error: 169.6039 - mean_absolute_error: 10.303 - ETA: 0s - loss: 169.7464 - mean_squared_error: 169.7464 - mean_absolute_error: 10.310 - ETA: 0s - loss: 170.3501 - mean_squared_error: 170.3501 - mean_absolute_error: 10.308 - ETA: 0s - loss: 171.3546 - mean_squared_error: 171.3546 - mean_absolute_error: 10.340 - ETA: 0s - loss: 171.0535 - mean_squared_error: 171.0535 - mean_absolute_error: 10.331 - ETA: 0s - loss: 171.9899 - mean_squared_error: 171.9899 - mean_absolute_error: 10.353 - ETA: 0s - loss: 173.0693 - mean_squared_error: 173.0693 - mean_absolute_error: 10.379 - ETA: 0s - loss: 172.9888 - mean_squared_error: 172.9888 - mean_absolute_error: 10.374 - ETA: 0s - loss: 174.0359 - mean_squared_error: 174.0359 - mean_absolute_error: 10.403 - ETA: 0s - loss: 173.5370 - mean_squared_error: 173.5370 - mean_absolute_error: 10.391 - ETA: 0s - loss: 173.7376 - mean_squared_error: 173.7376 - mean_absolute_error: 10.385 - ETA: 0s - loss: 174.4226 - mean_squared_error: 174.4226 - mean_absolute_error: 10.413 - ETA: 0s - loss: 173.8305 - mean_squared_error: 173.8305 - mean_absolute_error: 10.379 - ETA: 0s - loss: 173.6726 - mean_squared_error: 173.6726 - mean_absolute_error: 10.378 - 1s 119us/step - loss: 174.0618 - mean_squared_error: 174.0618 - mean_absolute_error: 10.3859
# Epoch 16/100
# 10380/10380 [==============================] - ETA: 2s - loss: 122.3951 - mean_squared_error: 122.3951 - mean_absolute_error: 8.24 - ETA: 1s - loss: 180.3615 - mean_squared_error: 180.3615 - mean_absolute_error: 10.337 - ETA: 1s - loss: 177.4744 - mean_squared_error: 177.4744 - mean_absolute_error: 10.551 - ETA: 1s - loss: 172.0197 - mean_squared_error: 172.0197 - mean_absolute_error: 10.401 - ETA: 1s - loss: 170.8152 - mean_squared_error: 170.8152 - mean_absolute_error: 10.352 - ETA: 0s - loss: 173.6572 - mean_squared_error: 173.6572 - mean_absolute_error: 10.422 - ETA: 0s - loss: 175.1422 - mean_squared_error: 175.1422 - mean_absolute_error: 10.474 - ETA: 0s - loss: 170.8510 - mean_squared_error: 170.8510 - mean_absolute_error: 10.354 - ETA: 0s - loss: 171.1574 - mean_squared_error: 171.1574 - mean_absolute_error: 10.355 - ETA: 0s - loss: 171.7250 - mean_squared_error: 171.7250 - mean_absolute_error: 10.382 - ETA: 0s - loss: 171.5292 - mean_squared_error: 171.5292 - mean_absolute_error: 10.373 - ETA: 0s - loss: 170.6360 - mean_squared_error: 170.6360 - mean_absolute_error: 10.328 - ETA: 0s - loss: 169.2675 - mean_squared_error: 169.2675 - mean_absolute_error: 10.280 - ETA: 0s - loss: 169.5459 - mean_squared_error: 169.5459 - mean_absolute_error: 10.274 - ETA: 0s - loss: 169.6435 - mean_squared_error: 169.6435 - mean_absolute_error: 10.276 - ETA: 0s - loss: 169.4661 - mean_squared_error: 169.4661 - mean_absolute_error: 10.255 - ETA: 0s - loss: 170.1969 - mean_squared_error: 170.1969 - mean_absolute_error: 10.284 - ETA: 0s - loss: 171.2615 - mean_squared_error: 171.2615 - mean_absolute_error: 10.292 - ETA: 0s - loss: 170.0067 - mean_squared_error: 170.0067 - mean_absolute_error: 10.257 - ETA: 0s - loss: 171.3265 - mean_squared_error: 171.3265 - mean_absolute_error: 10.293 - ETA: 0s - loss: 172.0967 - mean_squared_error: 172.0967 - mean_absolute_error: 10.326 - ETA: 0s - loss: 171.2696 - mean_squared_error: 171.2696 - mean_absolute_error: 10.299 - ETA: 0s - loss: 171.0838 - mean_squared_error: 171.0838 - mean_absolute_error: 10.295 - 1s 118us/step - loss: 171.1016 - mean_squared_error: 171.1016 - mean_absolute_error: 10.2941
# Epoch 17/100
# 10380/10380 [==============================] - ETA: 0s - loss: 147.1624 - mean_squared_error: 147.1624 - mean_absolute_error: 8.92 - ETA: 1s - loss: 168.2862 - mean_squared_error: 168.2862 - mean_absolute_error: 10.149 - ETA: 1s - loss: 168.7678 - mean_squared_error: 168.7678 - mean_absolute_error: 10.144 - ETA: 1s - loss: 174.3211 - mean_squared_error: 174.3211 - mean_absolute_error: 10.326 - ETA: 1s - loss: 173.6214 - mean_squared_error: 173.6214 - mean_absolute_error: 10.313 - ETA: 0s - loss: 175.5534 - mean_squared_error: 175.5534 - mean_absolute_error: 10.405 - ETA: 0s - loss: 176.4697 - mean_squared_error: 176.4697 - mean_absolute_error: 10.439 - ETA: 0s - loss: 174.1795 - mean_squared_error: 174.1795 - mean_absolute_error: 10.380 - ETA: 0s - loss: 175.0264 - mean_squared_error: 175.0264 - mean_absolute_error: 10.424 - ETA: 0s - loss: 172.6759 - mean_squared_error: 172.6759 - mean_absolute_error: 10.354 - ETA: 0s - loss: 172.6390 - mean_squared_error: 172.6390 - mean_absolute_error: 10.371 - ETA: 0s - loss: 173.5807 - mean_squared_error: 173.5807 - mean_absolute_error: 10.393 - ETA: 0s - loss: 173.7462 - mean_squared_error: 173.7462 - mean_absolute_error: 10.394 - ETA: 0s - loss: 175.0625 - mean_squared_error: 175.0625 - mean_absolute_error: 10.414 - ETA: 0s - loss: 174.0262 - mean_squared_error: 174.0262 - mean_absolute_error: 10.389 - ETA: 0s - loss: 173.8536 - mean_squared_error: 173.8536 - mean_absolute_error: 10.384 - ETA: 0s - loss: 172.6571 - mean_squared_error: 172.6571 - mean_absolute_error: 10.354 - ETA: 0s - loss: 173.1343 - mean_squared_error: 173.1343 - mean_absolute_error: 10.383 - ETA: 0s - loss: 172.0006 - mean_squared_error: 172.0006 - mean_absolute_error: 10.345 - ETA: 0s - loss: 171.2244 - mean_squared_error: 171.2244 - mean_absolute_error: 10.319 - ETA: 0s - loss: 171.1300 - mean_squared_error: 171.1300 - mean_absolute_error: 10.307 - ETA: 0s - loss: 170.9957 - mean_squared_error: 170.9957 - mean_absolute_error: 10.305 - ETA: 0s - loss: 170.8515 - mean_squared_error: 170.8515 - mean_absolute_error: 10.301 - 1s 117us/step - loss: 170.9542 - mean_squared_error: 170.9542 - mean_absolute_error: 10.2988
# Epoch 18/100
# 10380/10380 [==============================] - ETA: 0s - loss: 245.8262 - mean_squared_error: 245.8262 - mean_absolute_error: 11.182 - ETA: 1s - loss: 173.1511 - mean_squared_error: 173.1511 - mean_absolute_error: 10.455 - ETA: 1s - loss: 167.2811 - mean_squared_error: 167.2811 - mean_absolute_error: 10.189 - ETA: 1s - loss: 159.8455 - mean_squared_error: 159.8455 - mean_absolute_error: 9.889 - ETA: 1s - loss: 154.8486 - mean_squared_error: 154.8486 - mean_absolute_error: 9.71 - ETA: 0s - loss: 158.5594 - mean_squared_error: 158.5594 - mean_absolute_error: 9.83 - ETA: 0s - loss: 156.9501 - mean_squared_error: 156.9501 - mean_absolute_error: 9.80 - ETA: 0s - loss: 157.2527 - mean_squared_error: 157.2527 - mean_absolute_error: 9.82 - ETA: 0s - loss: 159.6814 - mean_squared_error: 159.6814 - mean_absolute_error: 9.92 - ETA: 0s - loss: 161.2869 - mean_squared_error: 161.2869 - mean_absolute_error: 9.96 - ETA: 0s - loss: 160.8604 - mean_squared_error: 160.8604 - mean_absolute_error: 9.95 - ETA: 0s - loss: 161.1774 - mean_squared_error: 161.1774 - mean_absolute_error: 9.96 - ETA: 0s - loss: 162.8032 - mean_squared_error: 162.8032 - mean_absolute_error: 10.014 - ETA: 0s - loss: 164.1218 - mean_squared_error: 164.1218 - mean_absolute_error: 10.043 - ETA: 0s - loss: 164.3801 - mean_squared_error: 164.3801 - mean_absolute_error: 10.041 - ETA: 0s - loss: 164.7377 - mean_squared_error: 164.7377 - mean_absolute_error: 10.044 - ETA: 0s - loss: 164.5655 - mean_squared_error: 164.5655 - mean_absolute_error: 10.051 - ETA: 0s - loss: 164.6778 - mean_squared_error: 164.6778 - mean_absolute_error: 10.056 - ETA: 0s - loss: 164.0624 - mean_squared_error: 164.0624 - mean_absolute_error: 10.053 - ETA: 0s - loss: 164.0952 - mean_squared_error: 164.0952 - mean_absolute_error: 10.063 - ETA: 0s - loss: 164.5866 - mean_squared_error: 164.5866 - mean_absolute_error: 10.080 - ETA: 0s - loss: 164.6963 - mean_squared_error: 164.6963 - mean_absolute_error: 10.086 - ETA: 0s - loss: 164.3409 - mean_squared_error: 164.3409 - mean_absolute_error: 10.085 - ETA: 0s - loss: 164.1292 - mean_squared_error: 164.1292 - mean_absolute_error: 10.084 - 1s 120us/step - loss: 164.1779 - mean_squared_error: 164.1779 - mean_absolute_error: 10.0897
# Epoch 19/100
# 10380/10380 [==============================] - ETA: 2s - loss: 106.6628 - mean_squared_error: 106.6628 - mean_absolute_error: 8.65 - ETA: 1s - loss: 171.9022 - mean_squared_error: 171.9022 - mean_absolute_error: 10.252 - ETA: 1s - loss: 167.5726 - mean_squared_error: 167.5726 - mean_absolute_error: 10.150 - ETA: 1s - loss: 164.6770 - mean_squared_error: 164.6770 - mean_absolute_error: 10.110 - ETA: 1s - loss: 165.6043 - mean_squared_error: 165.6043 - mean_absolute_error: 10.148 - ETA: 0s - loss: 162.2006 - mean_squared_error: 162.2006 - mean_absolute_error: 10.069 - ETA: 0s - loss: 164.6584 - mean_squared_error: 164.6584 - mean_absolute_error: 10.097 - ETA: 0s - loss: 165.3195 - mean_squared_error: 165.3195 - mean_absolute_error: 10.109 - ETA: 0s - loss: 168.5039 - mean_squared_error: 168.5039 - mean_absolute_error: 10.200 - ETA: 0s - loss: 167.9985 - mean_squared_error: 167.9985 - mean_absolute_error: 10.181 - ETA: 0s - loss: 167.8410 - mean_squared_error: 167.8410 - mean_absolute_error: 10.207 - ETA: 0s - loss: 167.6682 - mean_squared_error: 167.6682 - mean_absolute_error: 10.197 - ETA: 0s - loss: 166.1568 - mean_squared_error: 166.1568 - mean_absolute_error: 10.148 - ETA: 0s - loss: 166.1326 - mean_squared_error: 166.1326 - mean_absolute_error: 10.151 - ETA: 0s - loss: 166.8831 - mean_squared_error: 166.8831 - mean_absolute_error: 10.168 - ETA: 0s - loss: 167.0799 - mean_squared_error: 167.0799 - mean_absolute_error: 10.170 - ETA: 0s - loss: 166.2424 - mean_squared_error: 166.2424 - mean_absolute_error: 10.139 - ETA: 0s - loss: 166.7091 - mean_squared_error: 166.7091 - mean_absolute_error: 10.155 - ETA: 0s - loss: 166.2287 - mean_squared_error: 166.2287 - mean_absolute_error: 10.150 - ETA: 0s - loss: 166.9103 - mean_squared_error: 166.9103 - mean_absolute_error: 10.159 - ETA: 0s - loss: 167.0102 - mean_squared_error: 167.0102 - mean_absolute_error: 10.164 - ETA: 0s - loss: 166.9013 - mean_squared_error: 166.9013 - mean_absolute_error: 10.161 - ETA: 0s - loss: 166.4308 - mean_squared_error: 166.4308 - mean_absolute_error: 10.148 - ETA: 0s - loss: 166.3353 - mean_squared_error: 166.3353 - mean_absolute_error: 10.147 - 1s 118us/step - loss: 166.1356 - mean_squared_error: 166.1356 - mean_absolute_error: 10.1409
# Epoch 20/100
# 10380/10380 [==============================] - ETA: 2s - loss: 107.2280 - mean_squared_error: 107.2280 - mean_absolute_error: 9.37 - ETA: 1s - loss: 155.7925 - mean_squared_error: 155.7925 - mean_absolute_error: 9.96 - ETA: 1s - loss: 160.8633 - mean_squared_error: 160.8633 - mean_absolute_error: 10.100 - ETA: 1s - loss: 164.2834 - mean_squared_error: 164.2834 - mean_absolute_error: 10.196 - ETA: 0s - loss: 161.6791 - mean_squared_error: 161.6791 - mean_absolute_error: 10.057 - ETA: 0s - loss: 163.9149 - mean_squared_error: 163.9149 - mean_absolute_error: 10.177 - ETA: 0s - loss: 165.3454 - mean_squared_error: 165.3454 - mean_absolute_error: 10.205 - ETA: 0s - loss: 164.4946 - mean_squared_error: 164.4946 - mean_absolute_error: 10.160 - ETA: 0s - loss: 163.7977 - mean_squared_error: 163.7977 - mean_absolute_error: 10.115 - ETA: 0s - loss: 165.0915 - mean_squared_error: 165.0915 - mean_absolute_error: 10.157 - ETA: 0s - loss: 164.9854 - mean_squared_error: 164.9854 - mean_absolute_error: 10.145 - ETA: 0s - loss: 165.3209 - mean_squared_error: 165.3209 - mean_absolute_error: 10.173 - ETA: 0s - loss: 164.9923 - mean_squared_error: 164.9923 - mean_absolute_error: 10.163 - ETA: 0s - loss: 164.4400 - mean_squared_error: 164.4400 - mean_absolute_error: 10.153 - ETA: 0s - loss: 163.4842 - mean_squared_error: 163.4842 - mean_absolute_error: 10.121 - ETA: 0s - loss: 162.0286 - mean_squared_error: 162.0286 - mean_absolute_error: 10.065 - ETA: 0s - loss: 160.1957 - mean_squared_error: 160.1957 - mean_absolute_error: 10.009 - ETA: 0s - loss: 160.2665 - mean_squared_error: 160.2665 - mean_absolute_error: 10.003 - ETA: 0s - loss: 160.3210 - mean_squared_error: 160.3210 - mean_absolute_error: 9.996 - ETA: 0s - loss: 160.5203 - mean_squared_error: 160.5203 - mean_absolute_error: 10.008 - ETA: 0s - loss: 160.5846 - mean_squared_error: 160.5846 - mean_absolute_error: 10.002 - ETA: 0s - loss: 160.3155 - mean_squared_error: 160.3155 - mean_absolute_error: 9.997 - ETA: 0s - loss: 161.4700 - mean_squared_error: 161.4700 - mean_absolute_error: 10.039 - 1s 117us/step - loss: 161.5718 - mean_squared_error: 161.5718 - mean_absolute_error: 10.0499
# Epoch 21/100
# 10380/10380 [==============================] - ETA: 2s - loss: 169.5020 - mean_squared_error: 169.5020 - mean_absolute_error: 10.789 - ETA: 1s - loss: 184.1169 - mean_squared_error: 184.1169 - mean_absolute_error: 10.888 - ETA: 1s - loss: 167.4418 - mean_squared_error: 167.4418 - mean_absolute_error: 10.354 - ETA: 1s - loss: 163.2731 - mean_squared_error: 163.2731 - mean_absolute_error: 10.148 - ETA: 0s - loss: 162.2901 - mean_squared_error: 162.2901 - mean_absolute_error: 10.044 - ETA: 0s - loss: 164.7101 - mean_squared_error: 164.7101 - mean_absolute_error: 10.058 - ETA: 0s - loss: 167.4158 - mean_squared_error: 167.4158 - mean_absolute_error: 10.175 - ETA: 0s - loss: 165.9652 - mean_squared_error: 165.9652 - mean_absolute_error: 10.126 - ETA: 0s - loss: 163.6223 - mean_squared_error: 163.6223 - mean_absolute_error: 10.041 - ETA: 0s - loss: 164.2927 - mean_squared_error: 164.2927 - mean_absolute_error: 10.055 - ETA: 0s - loss: 162.9886 - mean_squared_error: 162.9886 - mean_absolute_error: 10.028 - ETA: 0s - loss: 162.2623 - mean_squared_error: 162.2623 - mean_absolute_error: 10.047 - ETA: 0s - loss: 162.1397 - mean_squared_error: 162.1397 - mean_absolute_error: 10.047 - ETA: 0s - loss: 161.2342 - mean_squared_error: 161.2342 - mean_absolute_error: 10.025 - ETA: 0s - loss: 160.8709 - mean_squared_error: 160.8709 - mean_absolute_error: 10.007 - ETA: 0s - loss: 162.1433 - mean_squared_error: 162.1433 - mean_absolute_error: 10.038 - ETA: 0s - loss: 162.2029 - mean_squared_error: 162.2029 - mean_absolute_error: 10.047 - ETA: 0s - loss: 162.2286 - mean_squared_error: 162.2286 - mean_absolute_error: 10.046 - ETA: 0s - loss: 162.6242 - mean_squared_error: 162.6242 - mean_absolute_error: 10.053 - ETA: 0s - loss: 162.6660 - mean_squared_error: 162.6660 - mean_absolute_error: 10.050 - ETA: 0s - loss: 162.2732 - mean_squared_error: 162.2732 - mean_absolute_error: 10.033 - ETA: 0s - loss: 162.2100 - mean_squared_error: 162.2100 - mean_absolute_error: 10.043 - ETA: 0s - loss: 162.7140 - mean_squared_error: 162.7140 - mean_absolute_error: 10.046 - ETA: 0s - loss: 162.1321 - mean_squared_error: 162.1321 - mean_absolute_error: 10.028 - 1s 119us/step - loss: 162.2267 - mean_squared_error: 162.2267 - mean_absolute_error: 10.0250
# Epoch 22/100
# ...
# Epoch 95/100
# 10380/10380 [==============================] - ETA: 3s - loss: 98.6402 - mean_squared_error: 98.6402 - mean_absolute_error: 8.12 - ETA: 1s - loss: 131.8069 - mean_squared_error: 131.8069 - mean_absolute_error: 8.97 - ETA: 1s - loss: 133.5919 - mean_squared_error: 133.5919 - mean_absolute_error: 9.07 - ETA: 1s - loss: 131.7776 - mean_squared_error: 131.7776 - mean_absolute_error: 9.01 - ETA: 1s - loss: 128.1606 - mean_squared_error: 128.1606 - mean_absolute_error: 8.94 - ETA: 1s - loss: 128.9931 - mean_squared_error: 128.9931 - mean_absolute_error: 8.96 - ETA: 0s - loss: 131.4073 - mean_squared_error: 131.4073 - mean_absolute_error: 9.03 - ETA: 0s - loss: 133.3756 - mean_squared_error: 133.3756 - mean_absolute_error: 9.11 - ETA: 0s - loss: 133.4096 - mean_squared_error: 133.4096 - mean_absolute_error: 9.11 - ETA: 0s - loss: 134.9213 - mean_squared_error: 134.9213 - mean_absolute_error: 9.11 - ETA: 0s - loss: 133.6338 - mean_squared_error: 133.6338 - mean_absolute_error: 9.06 - ETA: 0s - loss: 133.6913 - mean_squared_error: 133.6913 - mean_absolute_error: 9.06 - ETA: 0s - loss: 133.6547 - mean_squared_error: 133.6547 - mean_absolute_error: 9.05 - ETA: 0s - loss: 133.5060 - mean_squared_error: 133.5060 - mean_absolute_error: 9.05 - ETA: 0s - loss: 133.3020 - mean_squared_error: 133.3020 - mean_absolute_error: 9.06 - ETA: 0s - loss: 132.5999 - mean_squared_error: 132.5999 - mean_absolute_error: 9.05 - ETA: 0s - loss: 132.5690 - mean_squared_error: 132.5690 - mean_absolute_error: 9.06 - ETA: 0s - loss: 133.6884 - mean_squared_error: 133.6884 - mean_absolute_error: 9.09 - ETA: 0s - loss: 133.9407 - mean_squared_error: 133.9407 - mean_absolute_error: 9.09 - ETA: 0s - loss: 133.5870 - mean_squared_error: 133.5870 - mean_absolute_error: 9.09 - ETA: 0s - loss: 133.6181 - mean_squared_error: 133.6181 - mean_absolute_error: 9.08 - ETA: 0s - loss: 133.8500 - mean_squared_error: 133.8500 - mean_absolute_error: 9.08 - ETA: 0s - loss: 134.6322 - mean_squared_error: 134.6322 - mean_absolute_error: 9.11 - ETA: 0s - loss: 134.5974 - mean_squared_error: 134.5974 - mean_absolute_error: 9.10 - 1s 123us/step - loss: 135.4673 - mean_squared_error: 135.4673 - mean_absolute_error: 9.1340
# Epoch 96/100
# 10380/10380 [==============================] - ETA: 0s - loss: 90.4001 - mean_squared_error: 90.4001 - mean_absolute_error: 7.58 - ETA: 1s - loss: 124.0164 - mean_squared_error: 124.0164 - mean_absolute_error: 8.84 - ETA: 1s - loss: 135.1753 - mean_squared_error: 135.1753 - mean_absolute_error: 9.24 - ETA: 1s - loss: 132.4674 - mean_squared_error: 132.4674 - mean_absolute_error: 9.07 - ETA: 1s - loss: 131.9625 - mean_squared_error: 131.9625 - mean_absolute_error: 9.04 - ETA: 1s - loss: 136.4261 - mean_squared_error: 136.4261 - mean_absolute_error: 9.17 - ETA: 0s - loss: 131.7235 - mean_squared_error: 131.7235 - mean_absolute_error: 9.02 - ETA: 0s - loss: 129.9573 - mean_squared_error: 129.9573 - mean_absolute_error: 8.94 - ETA: 0s - loss: 127.6047 - mean_squared_error: 127.6047 - mean_absolute_error: 8.86 - ETA: 0s - loss: 127.4321 - mean_squared_error: 127.4321 - mean_absolute_error: 8.88 - ETA: 0s - loss: 126.8316 - mean_squared_error: 126.8316 - mean_absolute_error: 8.85 - ETA: 0s - loss: 127.5046 - mean_squared_error: 127.5046 - mean_absolute_error: 8.88 - ETA: 0s - loss: 128.8209 - mean_squared_error: 128.8209 - mean_absolute_error: 8.92 - ETA: 0s - loss: 129.6238 - mean_squared_error: 129.6238 - mean_absolute_error: 8.95 - ETA: 0s - loss: 131.0635 - mean_squared_error: 131.0635 - mean_absolute_error: 8.99 - ETA: 0s - loss: 131.3624 - mean_squared_error: 131.3624 - mean_absolute_error: 8.99 - ETA: 0s - loss: 130.0782 - mean_squared_error: 130.0782 - mean_absolute_error: 8.94 - ETA: 0s - loss: 130.1771 - mean_squared_error: 130.1771 - mean_absolute_error: 8.94 - ETA: 0s - loss: 130.5271 - mean_squared_error: 130.5271 - mean_absolute_error: 8.96 - ETA: 0s - loss: 131.0985 - mean_squared_error: 131.0985 - mean_absolute_error: 9.00 - ETA: 0s - loss: 132.2669 - mean_squared_error: 132.2669 - mean_absolute_error: 9.03 - ETA: 0s - loss: 132.1033 - mean_squared_error: 132.1033 - mean_absolute_error: 9.02 - ETA: 0s - loss: 132.4787 - mean_squared_error: 132.4787 - mean_absolute_error: 9.02 - ETA: 0s - loss: 133.4225 - mean_squared_error: 133.4225 - mean_absolute_error: 9.05 - ETA: 0s - loss: 133.1972 - mean_squared_error: 133.1972 - mean_absolute_error: 9.04 - 1s 125us/step - loss: 133.1171 - mean_squared_error: 133.1171 - mean_absolute_error: 9.0439
# Epoch 97/100
# 10380/10380 [==============================] - ETA: 2s - loss: 135.4703 - mean_squared_error: 135.4703 - mean_absolute_error: 9.53 - ETA: 1s - loss: 131.4416 - mean_squared_error: 131.4416 - mean_absolute_error: 8.96 - ETA: 1s - loss: 126.6310 - mean_squared_error: 126.6310 - mean_absolute_error: 8.80 - ETA: 1s - loss: 130.1492 - mean_squared_error: 130.1492 - mean_absolute_error: 8.91 - ETA: 1s - loss: 131.9870 - mean_squared_error: 131.9870 - mean_absolute_error: 8.96 - ETA: 1s - loss: 129.4505 - mean_squared_error: 129.4505 - mean_absolute_error: 8.84 - ETA: 0s - loss: 130.0154 - mean_squared_error: 130.0154 - mean_absolute_error: 8.88 - ETA: 0s - loss: 131.6814 - mean_squared_error: 131.6814 - mean_absolute_error: 8.96 - ETA: 0s - loss: 131.0357 - mean_squared_error: 131.0357 - mean_absolute_error: 8.95 - ETA: 0s - loss: 130.8401 - mean_squared_error: 130.8401 - mean_absolute_error: 8.96 - ETA: 0s - loss: 131.7500 - mean_squared_error: 131.7500 - mean_absolute_error: 8.99 - ETA: 0s - loss: 132.7807 - mean_squared_error: 132.7807 - mean_absolute_error: 9.05 - ETA: 0s - loss: 134.0309 - mean_squared_error: 134.0309 - mean_absolute_error: 9.10 - ETA: 0s - loss: 134.1011 - mean_squared_error: 134.1011 - mean_absolute_error: 9.10 - ETA: 0s - loss: 133.8808 - mean_squared_error: 133.8808 - mean_absolute_error: 9.09 - ETA: 0s - loss: 133.6287 - mean_squared_error: 133.6287 - mean_absolute_error: 9.08 - ETA: 0s - loss: 132.5796 - mean_squared_error: 132.5796 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.5900 - mean_squared_error: 133.5900 - mean_absolute_error: 9.06 - ETA: 0s - loss: 133.7160 - mean_squared_error: 133.7160 - mean_absolute_error: 9.06 - ETA: 0s - loss: 133.0238 - mean_squared_error: 133.0238 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.3666 - mean_squared_error: 133.3666 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.2552 - mean_squared_error: 133.2552 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.3283 - mean_squared_error: 133.3283 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.7535 - mean_squared_error: 133.7535 - mean_absolute_error: 9.05 - ETA: 0s - loss: 133.4672 - mean_squared_error: 133.4672 - mean_absolute_error: 9.04 - 1s 125us/step - loss: 132.8164 - mean_squared_error: 132.8164 - mean_absolute_error: 9.0251
# Epoch 98/100
# 10380/10380 [==============================] - ETA: 2s - loss: 70.4594 - mean_squared_error: 70.4594 - mean_absolute_error: 6.81 - ETA: 1s - loss: 142.5224 - mean_squared_error: 142.5224 - mean_absolute_error: 9.26 - ETA: 1s - loss: 140.4933 - mean_squared_error: 140.4933 - mean_absolute_error: 9.21 - ETA: 1s - loss: 137.1886 - mean_squared_error: 137.1886 - mean_absolute_error: 9.13 - ETA: 1s - loss: 134.1443 - mean_squared_error: 134.1443 - mean_absolute_error: 9.03 - ETA: 0s - loss: 132.1301 - mean_squared_error: 132.1301 - mean_absolute_error: 8.93 - ETA: 0s - loss: 129.8592 - mean_squared_error: 129.8592 - mean_absolute_error: 8.86 - ETA: 0s - loss: 129.5181 - mean_squared_error: 129.5181 - mean_absolute_error: 8.87 - ETA: 0s - loss: 130.3060 - mean_squared_error: 130.3060 - mean_absolute_error: 8.90 - ETA: 0s - loss: 130.4752 - mean_squared_error: 130.4752 - mean_absolute_error: 8.91 - ETA: 0s - loss: 131.8536 - mean_squared_error: 131.8536 - mean_absolute_error: 8.94 - ETA: 0s - loss: 132.9335 - mean_squared_error: 132.9335 - mean_absolute_error: 8.99 - ETA: 0s - loss: 132.4146 - mean_squared_error: 132.4146 - mean_absolute_error: 8.96 - ETA: 0s - loss: 132.2905 - mean_squared_error: 132.2905 - mean_absolute_error: 8.96 - ETA: 0s - loss: 131.8100 - mean_squared_error: 131.8100 - mean_absolute_error: 8.96 - ETA: 0s - loss: 130.2646 - mean_squared_error: 130.2646 - mean_absolute_error: 8.90 - ETA: 0s - loss: 129.4751 - mean_squared_error: 129.4751 - mean_absolute_error: 8.88 - ETA: 0s - loss: 129.2098 - mean_squared_error: 129.2098 - mean_absolute_error: 8.88 - ETA: 0s - loss: 129.0639 - mean_squared_error: 129.0639 - mean_absolute_error: 8.87 - ETA: 0s - loss: 128.9733 - mean_squared_error: 128.9733 - mean_absolute_error: 8.86 - ETA: 0s - loss: 128.6455 - mean_squared_error: 128.6455 - mean_absolute_error: 8.86 - ETA: 0s - loss: 128.8458 - mean_squared_error: 128.8458 - mean_absolute_error: 8.87 - ETA: 0s - loss: 129.2199 - mean_squared_error: 129.2199 - mean_absolute_error: 8.88 - ETA: 0s - loss: 129.8251 - mean_squared_error: 129.8251 - mean_absolute_error: 8.91 - ETA: 0s - loss: 130.4111 - mean_squared_error: 130.4111 - mean_absolute_error: 8.93 - 1s 124us/step - loss: 130.2954 - mean_squared_error: 130.2954 - mean_absolute_error: 8.9296
# Epoch 99/100
# 10380/10380 [==============================] - ETA: 2s - loss: 247.1373 - mean_squared_error: 247.1373 - mean_absolute_error: 13.002 - ETA: 1s - loss: 137.5523 - mean_squared_error: 137.5523 - mean_absolute_error: 8.937 - ETA: 1s - loss: 130.1778 - mean_squared_error: 130.1778 - mean_absolute_error: 8.84 - ETA: 1s - loss: 131.3227 - mean_squared_error: 131.3227 - mean_absolute_error: 8.93 - ETA: 1s - loss: 135.0365 - mean_squared_error: 135.0365 - mean_absolute_error: 9.03 - ETA: 1s - loss: 133.2609 - mean_squared_error: 133.2609 - mean_absolute_error: 8.95 - ETA: 1s - loss: 134.0005 - mean_squared_error: 134.0005 - mean_absolute_error: 8.97 - ETA: 0s - loss: 135.6528 - mean_squared_error: 135.6528 - mean_absolute_error: 9.03 - ETA: 0s - loss: 135.2387 - mean_squared_error: 135.2387 - mean_absolute_error: 9.02 - ETA: 0s - loss: 133.8180 - mean_squared_error: 133.8180 - mean_absolute_error: 8.97 - ETA: 0s - loss: 133.3432 - mean_squared_error: 133.3432 - mean_absolute_error: 8.95 - ETA: 0s - loss: 135.0280 - mean_squared_error: 135.0280 - mean_absolute_error: 9.01 - ETA: 0s - loss: 135.4793 - mean_squared_error: 135.4793 - mean_absolute_error: 9.04 - ETA: 0s - loss: 135.2476 - mean_squared_error: 135.2476 - mean_absolute_error: 9.02 - ETA: 0s - loss: 135.8608 - mean_squared_error: 135.8608 - mean_absolute_error: 9.05 - ETA: 0s - loss: 136.5069 - mean_squared_error: 136.5069 - mean_absolute_error: 9.08 - ETA: 0s - loss: 136.0010 - mean_squared_error: 136.0010 - mean_absolute_error: 9.06 - ETA: 0s - loss: 135.8553 - mean_squared_error: 135.8553 - mean_absolute_error: 9.07 - ETA: 0s - loss: 135.2029 - mean_squared_error: 135.2029 - mean_absolute_error: 9.05 - ETA: 0s - loss: 134.5207 - mean_squared_error: 134.5207 - mean_absolute_error: 9.02 - ETA: 0s - loss: 134.3880 - mean_squared_error: 134.3880 - mean_absolute_error: 9.03 - ETA: 0s - loss: 133.5842 - mean_squared_error: 133.5842 - mean_absolute_error: 9.01 - ETA: 0s - loss: 133.6029 - mean_squared_error: 133.6029 - mean_absolute_error: 9.01 - ETA: 0s - loss: 133.1751 - mean_squared_error: 133.1751 - mean_absolute_error: 9.00 - ETA: 0s - loss: 132.6127 - mean_squared_error: 132.6127 - mean_absolute_error: 8.98 - 1s 130us/step - loss: 132.1775 - mean_squared_error: 132.1775 - mean_absolute_error: 8.9697
# Epoch 100/100
# 10380/10380 [==============================] - ETA: 2s - loss: 103.8473 - mean_squared_error: 103.8473 - mean_absolute_error: 8.66 - ETA: 1s - loss: 142.5418 - mean_squared_error: 142.5418 - mean_absolute_error: 9.34 - ETA: 1s - loss: 134.4759 - mean_squared_error: 134.4759 - mean_absolute_error: 9.14 - ETA: 1s - loss: 131.7687 - mean_squared_error: 131.7687 - mean_absolute_error: 9.08 - ETA: 1s - loss: 132.8182 - mean_squared_error: 132.8182 - mean_absolute_error: 9.04 - ETA: 1s - loss: 128.9123 - mean_squared_error: 128.9123 - mean_absolute_error: 8.93 - ETA: 1s - loss: 130.0421 - mean_squared_error: 130.0421 - mean_absolute_error: 8.92 - ETA: 0s - loss: 131.6770 - mean_squared_error: 131.6770 - mean_absolute_error: 9.00 - ETA: 0s - loss: 133.7244 - mean_squared_error: 133.7244 - mean_absolute_error: 9.03 - ETA: 0s - loss: 136.3464 - mean_squared_error: 136.3464 - mean_absolute_error: 9.11 - ETA: 0s - loss: 133.8044 - mean_squared_error: 133.8044 - mean_absolute_error: 9.03 - ETA: 0s - loss: 132.7217 - mean_squared_error: 132.7217 - mean_absolute_error: 9.00 - ETA: 0s - loss: 133.7613 - mean_squared_error: 133.7613 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.2231 - mean_squared_error: 133.2231 - mean_absolute_error: 9.01 - ETA: 0s - loss: 133.7776 - mean_squared_error: 133.7776 - mean_absolute_error: 9.04 - ETA: 0s - loss: 134.2252 - mean_squared_error: 134.2252 - mean_absolute_error: 9.05 - ETA: 0s - loss: 133.7202 - mean_squared_error: 133.7202 - mean_absolute_error: 9.04 - ETA: 0s - loss: 133.4954 - mean_squared_error: 133.4954 - mean_absolute_error: 9.03 - ETA: 0s - loss: 133.3680 - mean_squared_error: 133.3680 - mean_absolute_error: 9.03 - ETA: 0s - loss: 132.5804 - mean_squared_error: 132.5804 - mean_absolute_error: 9.01 - ETA: 0s - loss: 132.4515 - mean_squared_error: 132.4515 - mean_absolute_error: 9.01 - ETA: 0s - loss: 131.9325 - mean_squared_error: 131.9325 - mean_absolute_error: 8.98 - ETA: 0s - loss: 132.6711 - mean_squared_error: 132.6711 - mean_absolute_error: 9.00 - ETA: 0s - loss: 132.4346 - mean_squared_error: 132.4346 - mean_absolute_error: 8.99 - ETA: 0s - loss: 132.6555 - mean_squared_error: 132.6555 - mean_absolute_error: 9.00 - 1s 127us/step - loss: 132.3578 - mean_squared_error: 132.3578 - mean_absolute_error: 9.0026

# %%
"""Classification: Test set predictions """
# y_proba = model.predict(X_test)
# y_pred = pd.Series(y_proba.argmax(axis=-1))

# Classification, if using pd.get_dummies:
# y_t = pd.Series(y_test.columns[np.where(y_test != 0)[1]])

# Classification, if using OneHotEncoder:
# y_t = csr_matrix.argmax(y_test, axis=1)
# y_t = pd.Series(np.squeeze(np.asarray(y_t)))

# Regression, use 'y_test'
# Out:
# 'Classification: Test set predictions '

# %%
"""
Regression
True y, not needed for kappa metric because already passed with train, test, split
Used to verify reverse scaling
"""
y_pred = pd.DataFrame(model.predict(X_test).reshape(-1))

# %%
"""Reverse scaling back to original target score scales"""

# Merge results
results = scores_test.reset_index(drop=True)\
                    .join(y_pred)\
                    .rename(columns={0:'y_pred'})\
                    .sort_values(by='topic')\
                    .reset_index(drop=True)
results.head()
# Out:
#    index  topic  target_score  scaled     y_pred
# 0   1751      1            10    48.0  45.578049
# 1   1075      1            12    60.0  50.880726
# 2    383      1            10    48.0  45.685986
# 3    706      1            10    48.0  44.890186
# 4    831      1            10    48.0  47.441628

# %% [markdown]
# Prior to down-scaling, which includes some amount of rounding, we see the model tends to avoid predicting the highest or lowest scores. This is possibly due to class imbalance of the data set.

# %%
# score histogram

results[['scaled', 'y_pred']].plot.hist(histtype='step', bins=10)
plt.title('Histogram of scaled target scores')
plt.xlabel('target score')
plt.ylabel('count')
plt.show()

# %%
""" Create list of tuples with min/max target scores sorted by topic number.
 Performed here on results in case min/max values didn't pass through train_test_split"""
score_df = results.groupby('topic')['target_score'].agg(['min', 'max'])  
score_ranges = list(zip(score_df['min'], score_df['max'])) 

"""Shrink back to original range by topic number:"""
y_p_df = pd.Series()
y_t_df = pd.Series()

for topic in range(1,9):
    scaler = MinMaxScaler(score_ranges[topic-1])
    scaled_pred = results[results.topic == topic]['y_pred'].to_frame()
    y_pred_shrunk = scaler.fit_transform(scaled_pred).round(0).astype('int')
    scaled_true = results[results.topic == topic]['scaled'].to_frame()
    y_true_shrunk = scaler.fit_transform(scaled_true).round(0).astype('int')
    y_p_df = y_p_df.append(pd.Series(np.squeeze(np.asarray(y_pred_shrunk))), ignore_index=True)
    y_t_df = y_t_df.append(pd.Series(np.squeeze(np.asarray(y_true_shrunk))), ignore_index=True)
    
# Append to results df
results['pred'] = y_p_df
results['y_true'] = y_t_df
results.head()
# Out:
#    index  topic  target_score  scaled     y_pred  pred  y_true
# 0   1751      1            10    48.0  45.578049    10      10
# 1   1075      1            12    60.0  50.880726    11      12
# 2    383      1            10    48.0  45.685986    10      10
# 3    706      1            10    48.0  44.890186    10      10
# 4    831      1            10    48.0  47.441628    11      10

# %%
# Classification accuracy:
# print("Training accuracy: %.2f%% / Validation accuracy: %.2f%%" % 
#       (100*estimator.history['acc'][-1], 100*estimator.history['val_acc'][-1]))

# %% [markdown]
# ### A note on kappa scores
#
# Some previous studies apply the kappa metric directly to the complete set of essays. Due to the differences in scale, essay topics (sets) that have a narrow scoring range will end up with significantly smaller weighted distances and thus artificially high kappa scores. Kappa scores of up to 94.5% have been reported with this metric.
#
# Other studies calculate the kappa score for each topic individually and then report the geometric mean.
#
# The "correct" method, i.e. the method used in the original Kaggle competition, uses the quadratic weighted kappa for each set individually and then calculates the mean of the quadratic weighted kappas after applying Fisher's r-to-z transform, which is approximately a variance-stabilizing transformation. Each set is weighted by a factor of one, except for topic 2 which has two domain raters which are each weighted 0.5. It is not clear why the scores are not weighted by the number of essays in each set, then again, the actual formulas used in the competition have not been published.
#
# The kappa scores from the original competition were based on comparison to unpublished test data scores. Since all published work on this data set only used the training data set, kappas cannot be compared directly to competition results.
#
# Finally, most published work used a subset of essay sets (topics). Omitting topics is likel going to change kappa scores for better or worse.

# %%
k = kappa(results.pred, results.target_score, weights='quadratic')
print('Combined essay Kappa score: {:.2f}%'.format(k * 100))
# Out:
# Combined essay Kappa score: 97.80%

# %%
from bhkappa import kappabh, confusion_matrix, histogram, quadratic_weighted_kappa, linear_weighted_kappa, mean_quadratic_weighted_kappa

qwk = []
weights = []
for topic in range(1,9):
    qwk.append(
            quadratic_weighted_kappa(
                results[results.topic == topic]['target_score'], results[results.topic == topic]['pred'],
                    score_ranges[topic-1][0], score_ranges[topic-1][1]))
    weights.append(len(results[results.topic==topic])/X_test.shape[0])    
mqwk = mean_quadratic_weighted_kappa(qwk, weights=weights)
print('Weighted by topic Kappa score: {:.2f}%'.format(mqwk * 100))
# Out:
# Weighted by topic Kappa score: 65.73%

# %%
qwk
# Out:
# [0.7537044066836954,
#  0.4858679632137396,
#  0.5702330821017623,
#  0.6582063950203889,
#  0.6999302310831095,
#  0.674481772694782,
#  0.740512114432142,
#  0.5833266964001274]

# %%
topic_number = 0
fig, ax = plt.subplots(4,2, figsize=(8,8), sharey=False)
for i in range(4):
    for j in range(2):
        topic_number += 1
        results[results['topic'] == topic_number]\
            .groupby('y_true')['y_true']\
            .agg('count')\
            .plot.bar(ax=ax[i, j], rot=0, fill=False, ec='b', label='actual')
        results[results['topic'] == topic_number]\
            .groupby('pred')['pred']\
            .agg('count')\
            .plot.bar(ax=ax[i, j], rot=0, fill=False, ec='r', label='prediction')
        ax[i,j].set_title('Topic %i' % topic_number)
ax[3,0].locator_params(nbins=10)
ax[3,1].locator_params(nbins=10)
plt.suptitle('Histograms of predicted essay scores')
plt.legend(bbox_to_anchor=(1.0, 1.05))
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
"""
Use this for plotting regression mean-squared error
Validation split must be enabled during model fit.
"""
# Plot model mse over epochs
sns.reset_orig()   # Reset seaborn settings to get rid of black background
plt.plot(estimator.history['mean_squared_error'])
plt.plot(estimator.history['val_mean_squared_error'])
plt.title('model MSE')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
# plt.ylim(0,300)
plt.show()

# Plot model loss over epochs
plt.plot(estimator.history['loss'])
plt.plot(estimator.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
"""Use this for plotting classification accuracy"""
# # Plot model accuracy over epochs
# sns.reset_orig()   # Reset seaborn settings to get rid of black background
# plt.plot(estimator.history['acc'])
# plt.plot(estimator.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'valid'], loc='upper left')
# plt.show()

# # Plot model loss over epochs
# plt.plot(estimator.history['loss'])
# plt.plot(estimator.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'valid'], loc='upper left')
# plt.show()

# %%
# Check for scaling errors
errors = len(results.query('y_true != target_score')[['topic', 'target_score', 'y_true']])

print('{:.1f}% of target scores did not revert back to their original value.'.format(errors/results.shape[0] * 100))
# Out:
# 0.0% of target scores did not revert back to their original value.
